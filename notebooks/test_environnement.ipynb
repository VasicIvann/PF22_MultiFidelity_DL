# %%
import torch
import os
from google.colab import drive

print("--- 🚀 TEST DE L'ENVIRONNEMENT UTBM PF22 ---")

# 1. Test du GPU (Colab)
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print(f"✅ GPU DÉTECTÉ : {gpu_name}")
else:
    print("❌ ERREUR : Aucun GPU détecté. Vérifie le type de Kernel.")

# 2. Test du montage Google Drive
print("\nTentative de connexion à Google Drive...")
drive.mount('/content/drive')
print("✅ GOOGLE DRIVE MONTÉ AVEC SUCCÈS !")

# 3. Test d'écriture sur le Drive
test_path = '/content/drive/MyDrive/UTBM_PF22_Test'
os.makedirs(test_path, exist_ok=True)

test_file = os.path.join(test_path, 'hello_pf22.txt')
with open(test_file, 'w') as f:
    f.write('Si tu lis ceci, la connexion VS Code -> Colab -> Drive fonctionne parfaitement !')

print(f"\n✅ FICHIER DE TEST CRÉÉ SUR LE DRIVE ICI : {test_file}")
print("--- TEST TERMINÉ AVEC SUCCÈS ---")
# Out:
# Mounted at /content/drive
# ✅ GOOGLE DRIVE MONTÉ AVEC SUCCÈS !
#
# ✅ FICHIER DE TEST CRÉÉ SUR LE DRIVE ICI : /content/drive/MyDrive/UTBM_PF22_Test/hello_pf22.txt
# --- TEST TERMINÉ AVEC SUCCÈS ---
