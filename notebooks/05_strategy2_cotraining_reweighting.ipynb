# %% [markdown]
# # Partie 4 - Etape 2: Strategie 2 Co-training par Batch avec Ponderation
#
# Cette experience implemente un **co-training HF+BF simultane** avec deux mecanismes:
# - un **ratio fixe HF/BF par batch** via un batch sampler personnalise,
# - une **loss ponderee par domaine** qui donne plus d'importance aux echantillons HF.
#
# ## Objectif
# - Preserver une forte performance sur Test HF (objectif prioritaire).
# - Maintenir une robustesse raisonnable sur BF.
# - Evaluer le compromis performance / cout en CA.

# %%
import os
import json
import time
import random
import shutil

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split, Sampler
from torchvision import datasets, transforms, models
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.benchmark = True
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Appareil: {device}')
# Out:
# Appareil: cuda

# %% [markdown]
# ## 1) Montage Drive et chemins de travail
# Continuite avec les notebooks precedents: SSD local prioritaire, puis fallback Drive.

# %%
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive', force_remount=True)

    local_base = '/content/processed_multifidelity'
    zip_source = '/content/drive/MyDrive/UTBM_PF22/datasets/Animals-10/dataset_multifidelity.zip'
    drive_base_candidates = [
        '/content/drive/MyDrive/UTBM_PF22/datasets/Animals-10/processed_multifidelity',
        '/content/drive/MyDrive/UTBM_PF22/results/datasets/Animals-10/processed_multifidelity',
    ]

    if os.path.exists(local_base):
        print('Dataset deja present sur SSD local, reutilisation.')
        BASE_DIR = local_base
    else:
        if os.path.exists(zip_source):
            print('Extraction du zip dataset vers SSD local...')
            start = time.time()
            shutil.copy2(zip_source, '/content/dataset_multifidelity.zip')
            import zipfile
            with zipfile.ZipFile('/content/dataset_multifidelity.zip', 'r') as zip_ref:
                zip_ref.extractall('/content/')
            os.remove('/content/dataset_multifidelity.zip')
            print(f'Dataset extrait sur SSD en {time.time()-start:.2f}s')
            BASE_DIR = local_base if os.path.exists(local_base) else None
        else:
            BASE_DIR = None

        if BASE_DIR is None:
            drive_base = next((p for p in drive_base_candidates if os.path.exists(p)), None)
            if drive_base is None:
                raise FileNotFoundError(
                    'Aucun dataset trouve. Chemins testes: '
                    + ' | '.join([zip_source] + drive_base_candidates)
                )
            print('SSD indisponible, fallback vers le dossier Drive deja prepare.')
            BASE_DIR = drive_base

    RESULTS_DIR = '/content/drive/MyDrive/UTBM_PF22/results'
else:
    candidate_base_dirs = [
        '../data/processed_multifidelity',
        './data/processed_multifidelity',
        'data/processed_multifidelity',
    ]
    BASE_DIR = next((p for p in candidate_base_dirs if os.path.exists(p)), None)
    if BASE_DIR is None:
        raise FileNotFoundError(
            'Aucun dossier processed_multifidelity trouve. Chemins testes: '
            + ' | '.join(candidate_base_dirs)
        )
    RESULTS_DIR = '../results'

os.makedirs(RESULTS_DIR, exist_ok=True)
print('BASE_DIR selectionne =', BASE_DIR)
print('RESULTS_DIR         =', RESULTS_DIR)
# Out:
# Mounted at /content/drive
# Dataset deja present sur SSD local, reutilisation.
# BASE_DIR selectionne = /content/processed_multifidelity
# RESULTS_DIR         = /content/drive/MyDrive/UTBM_PF22/results

# %% [markdown]
# ## 2) Configuration, datasets et transforms

# %%
COST_HF = 10
COST_BF = 1
BATCH_SIZE = 64
NUM_WORKERS = 2 if '/content/processed_multifidelity' in str(BASE_DIR) else 0
EPOCHS = 20
LR = 1e-3
HF_TRAIN_RATIO = 0.8
HF_BATCH_RATIO = 0.25
HF_LOSS_WEIGHT = 2.0
BF_LOSS_WEIGHT = 0.7

class AddDegradationTransform:
    """Degrade un tenseur image pour simuler le domaine BF."""
    def __call__(self, img_tensor):
        h, w = img_tensor.shape[1], img_tensor.shape[2]
        img_degraded = transforms.functional.resize(img_tensor, (64, 64), antialias=True)
        img_degraded = transforms.functional.resize(img_degraded, (h, w), antialias=True)
        noise = torch.randn_like(img_degraded) * 0.15
        img_noisy = img_degraded + noise
        return torch.clamp(img_noisy, 0, 1)

transform_standard = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_bf_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    AddDegradationTransform(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

required_dirs = [
    os.path.join(BASE_DIR, 'train', 'HF'),
    os.path.join(BASE_DIR, 'train', 'BF'),
    os.path.join(BASE_DIR, 'test'),
]
missing = [p for p in required_dirs if not os.path.isdir(p)]
if missing:
    raise FileNotFoundError(
        'Structure dataset invalide. Dossiers manquants: ' + ' | '.join(missing)
    )

dataset_hf_full = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/HF'), transform=transform_standard)
dataset_bf_train = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/BF'), transform=transform_standard)
dataset_test_hf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_standard)
dataset_test_bf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_bf_test)

hf_train_size = int(HF_TRAIN_RATIO * len(dataset_hf_full))
hf_val_size = len(dataset_hf_full) - hf_train_size
dataset_hf_train, dataset_hf_val = random_split(
    dataset_hf_full,
    [hf_train_size, hf_val_size],
    generator=torch.Generator().manual_seed(SEED)
)

loader_hf_val = DataLoader(dataset_hf_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_hf = DataLoader(dataset_test_hf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_bf = DataLoader(dataset_test_bf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f'HF train: {len(dataset_hf_train)} | HF val: {len(dataset_hf_val)}')
print(f'BF train: {len(dataset_bf_train)} | Test HF/BF: {len(dataset_test_hf)}')
print(f'NUM_WORKERS utilise: {NUM_WORKERS}')
# Out:
# HF train: 1881 | HF val: 471
# BF train: 21213 | Test HF/BF: 2614
# NUM_WORKERS utilise: 2

# %% [markdown]
# ## 3) Batch sampler mixte HF/BF (ratio fixe par batch)
# On construit un dataset concatene avec un indicateur de domaine, puis un sampler qui force une composition fixe de chaque lot.

# %%
class DomainLabeledConcatDataset(Dataset):
    def __init__(self, hf_dataset, bf_dataset):
        self.hf_dataset = hf_dataset
        self.bf_dataset = bf_dataset
        self.hf_len = len(hf_dataset)
        self.bf_len = len(bf_dataset)

    def __len__(self):
        return self.hf_len + self.bf_len

    def __getitem__(self, idx):
        if idx < self.hf_len:
            x, y = self.hf_dataset[idx]
            domain = 1
        else:
            x, y = self.bf_dataset[idx - self.hf_len]
            domain = 0
        return x, y, domain

class MixedBatchSampler(Sampler):
    def __init__(self, hf_indices, bf_indices, batch_size, hf_ratio=0.25, seed=42, drop_last=True):
        self.hf_indices = list(hf_indices)
        self.bf_indices = list(bf_indices)
        self.batch_size = int(batch_size)
        self.hf_ratio = float(hf_ratio)
        self.drop_last = drop_last
        self.seed = int(seed)
        self.epoch = 0

        self.hf_per_batch = max(1, int(round(self.batch_size * self.hf_ratio)))
        self.bf_per_batch = self.batch_size - self.hf_per_batch
        if self.bf_per_batch <= 0:
            raise ValueError('hf_ratio trop grand: bf_per_batch <= 0')

        self.num_batches = min(
            len(self.hf_indices) // self.hf_per_batch,
            len(self.bf_indices) // self.bf_per_batch
        )
        if self.num_batches <= 0:
            raise ValueError('Pas assez de donnees pour former un seul batch mixte.')

    def __len__(self):
        return self.num_batches

    def set_epoch(self, epoch):
        self.epoch = int(epoch)

    def __iter__(self):
        g = torch.Generator()
        g.manual_seed(self.seed + self.epoch)

        hf_perm = torch.randperm(len(self.hf_indices), generator=g).tolist()
        bf_perm = torch.randperm(len(self.bf_indices), generator=g).tolist()

        for b in range(self.num_batches):
            h0 = b * self.hf_per_batch
            h1 = h0 + self.hf_per_batch
            b0 = b * self.bf_per_batch
            b1 = b0 + self.bf_per_batch

            batch_hf = [self.hf_indices[i] for i in hf_perm[h0:h1]]
            batch_bf = [self.bf_indices[i] for i in bf_perm[b0:b1]]
            batch = batch_hf + batch_bf

            order = torch.randperm(len(batch), generator=g).tolist()
            yield [batch[i] for i in order]

mixed_train_dataset = DomainLabeledConcatDataset(dataset_hf_train, dataset_bf_train)
hf_indices = list(range(len(dataset_hf_train)))
bf_offset = len(dataset_hf_train)
bf_indices = list(range(bf_offset, bf_offset + len(dataset_bf_train)))

mixed_batch_sampler = MixedBatchSampler(
    hf_indices=hf_indices,
    bf_indices=bf_indices,
    batch_size=BATCH_SIZE,
    hf_ratio=HF_BATCH_RATIO,
    seed=SEED,
    drop_last=True
)

loader_mixed_train = DataLoader(
    mixed_train_dataset,
    batch_sampler=mixed_batch_sampler,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

print(f'Batches/epoch: {len(loader_mixed_train)}')
print(f'Composition batch: HF={mixed_batch_sampler.hf_per_batch}, BF={mixed_batch_sampler.bf_per_batch}')
print(f'Ratio HF reel par batch: {mixed_batch_sampler.hf_per_batch / BATCH_SIZE:.3f}')
# Out:
# Batches/epoch: 117
# Composition batch: HF=16, BF=48
# Ratio HF reel par batch: 0.250

# %% [markdown]
# ## 4) Modele, loss ponderee et utilitaires

# %%
def create_model(num_classes=10):
    model = models.resnet18(weights=None)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)
            total_loss += loss.item() * x.size(0)
            total_correct += (logits.argmax(dim=1) == y).sum().item()
            total_samples += x.size(0)
    return total_loss / total_samples, 100.0 * total_correct / total_samples

def make_grad_scaler():
    try:
        return GradScaler('cuda', enabled=(device.type == 'cuda'))
    except TypeError:
        return GradScaler(enabled=(device.type == 'cuda'))

def train_cotraining_weighted(model, train_loader, sampler, val_loader, epochs, lr, hf_w, bf_w):
    ce_none = nn.CrossEntropyLoss(reduction='none')
    ce_mean = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = make_grad_scaler()

    history = {
        'train_weighted_loss': [],
        'train_hf_loss': [],
        'train_bf_loss': [],
        'val_loss': [],
        'val_acc': []
    }

    print(f'Loss weights utilises: HF={hf_w} | BF={bf_w}')
    print(f'Ratio batch cible: HF={sampler.hf_per_batch}/{BATCH_SIZE} | BF={sampler.bf_per_batch}/{BATCH_SIZE}')

    for epoch in range(1, epochs + 1):
        sampler.set_epoch(epoch)
        model.train()

        total_weighted = 0.0
        total_samples = 0
        hf_loss_sum = 0.0
        hf_count = 0
        bf_loss_sum = 0.0
        bf_count = 0

        epoch_start = time.time()
        log_every = 10

        for batch_idx, (x, y, domain) in enumerate(train_loader, start=1):
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            domain = domain.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                per_sample_loss = ce_none(logits, y)
                sample_weights = torch.where(
                    domain == 1,
                    torch.full_like(per_sample_loss, float(hf_w)),
                    torch.full_like(per_sample_loss, float(bf_w))
                )
                weighted_loss = (per_sample_loss * sample_weights).mean()

            scaler.scale(weighted_loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_weighted += weighted_loss.item() * x.size(0)
            total_samples += x.size(0)

            hf_mask = (domain == 1)
            bf_mask = (domain == 0)
            if hf_mask.any():
                hf_loss_sum += per_sample_loss[hf_mask].detach().sum().item()
                hf_count += int(hf_mask.sum().item())
            if bf_mask.any():
                bf_loss_sum += per_sample_loss[bf_mask].detach().sum().item()
                bf_count += int(bf_mask.sum().item())

            if batch_idx == 1:
                n_hf_batch = int(hf_mask.sum().item())
                n_bf_batch = int(bf_mask.sum().item())
                print(f'Epoch {epoch}: composition premier batch HF={n_hf_batch}, BF={n_bf_batch}')

            if batch_idx % log_every == 0 or batch_idx == 1 or batch_idx == len(train_loader):
                elapsed = time.time() - epoch_start
                bps = batch_idx / elapsed if elapsed > 0 else 0.0
                eta_sec = (len(train_loader) - batch_idx) / bps if bps > 0 else 0.0
                print(
                    f'[CoTrain] Epoch {epoch}/{epochs} | Batch {batch_idx}/{len(train_loader)} | '
                    f'weighted_loss={weighted_loss.item():.4f} | {bps:.2f} batch/s | ETA={eta_sec/60:.1f} min'
                )

        train_weighted_loss = total_weighted / max(1, total_samples)
        train_hf_loss = hf_loss_sum / max(1, hf_count)
        train_bf_loss = bf_loss_sum / max(1, bf_count)
        val_loss, val_acc = evaluate(model, val_loader, ce_mean)
        epoch_min = (time.time() - epoch_start) / 60.0

        history['train_weighted_loss'].append(train_weighted_loss)
        history['train_hf_loss'].append(train_hf_loss)
        history['train_bf_loss'].append(train_bf_loss)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(
            f'[CoTrain] Epoch {epoch}/{epochs} en {epoch_min:.2f} min | '
            f'weighted={train_weighted_loss:.4f} | hf_loss={train_hf_loss:.4f} | '
            f'bf_loss={train_bf_loss:.4f} | val_loss={val_loss:.4f} | val_acc={val_acc:.2f}%'
        )

    return history

# %% [markdown]
# ## 5) Execution Strategie 2 (co-training pondéré)

# %%
model = create_model(num_classes=10)
print('Modele initialise:', model.__class__.__name__)

start_train = time.time()
history = train_cotraining_weighted(
    model=model,
    train_loader=loader_mixed_train,
    sampler=mixed_batch_sampler,
    val_loader=loader_hf_val,
    epochs=EPOCHS,
    lr=LR,
    hf_w=HF_LOSS_WEIGHT,
    bf_w=BF_LOSS_WEIGHT
)
training_time_min = (time.time() - start_train) / 60.0
print(f'Entrainement termine en {training_time_min:.2f} min')
# Out:
# Modele initialise: ResNet
# Loss weights utilises: HF=2.0 | BF=0.7
# Ratio batch cible: HF=16/64 | BF=48/64
# Epoch 1: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 1/20 | Batch 1/117 | weighted_loss=2.4836 | 0.06 batch/s | ETA=30.1 min
# [CoTrain] Epoch 1/20 | Batch 10/117 | weighted_loss=2.4047 | 0.61 batch/s | ETA=2.9 min
# [CoTrain] Epoch 1/20 | Batch 20/117 | weighted_loss=2.1798 | 1.13 batch/s | ETA=1.4 min
# [CoTrain] Epoch 1/20 | Batch 30/117 | weighted_loss=2.1464 | 1.59 batch/s | ETA=0.9 min
# [CoTrain] Epoch 1/20 | Batch 40/117 | weighted_loss=1.9851 | 2.02 batch/s | ETA=0.6 min
# [CoTrain] Epoch 1/20 | Batch 50/117 | weighted_loss=2.0373 | 2.38 batch/s | ETA=0.5 min
# [CoTrain] Epoch 1/20 | Batch 60/117 | weighted_loss=2.2501 | 2.71 batch/s | ETA=0.4 min
# [CoTrain] Epoch 1/20 | Batch 70/117 | weighted_loss=1.8358 | 3.03 batch/s | ETA=0.3 min
# [CoTrain] Epoch 1/20 | Batch 80/117 | weighted_loss=2.4117 | 3.26 batch/s | ETA=0.2 min
# [CoTrain] Epoch 1/20 | Batch 90/117 | weighted_loss=1.9225 | 3.53 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 100/117 | weighted_loss=2.1027 | 3.77 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 110/117 | weighted_loss=1.8857 | 3.97 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 117/117 | weighted_loss=1.9156 | 4.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 en 0.50 min | weighted=2.1480 | hf_loss=2.0929 | bf_loss=2.0982 | val_loss=1.9485 | val_acc=30.57%
# Epoch 2: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 2/20 | Batch 1/117 | weighted_loss=2.0275 | 2.81 batch/s | ETA=0.7 min
# [CoTrain] Epoch 2/20 | Batch 10/117 | weighted_loss=1.6400 | 8.34 batch/s | ETA=0.2 min
# [CoTrain] Epoch 2/20 | Batch 20/117 | weighted_loss=1.8070 | 7.81 batch/s | ETA=0.2 min
# [CoTrain] Epoch 2/20 | Batch 30/117 | weighted_loss=1.9264 | 8.39 batch/s | ETA=0.2 min
# [CoTrain] Epoch 2/20 | Batch 40/117 | weighted_loss=1.7522 | 8.75 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 50/117 | weighted_loss=1.7873 | 8.98 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 60/117 | weighted_loss=1.7574 | 9.15 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 70/117 | weighted_loss=1.6514 | 8.87 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 80/117 | weighted_loss=1.8651 | 9.01 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 90/117 | weighted_loss=1.8568 | 9.04 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 100/117 | weighted_loss=1.8552 | 8.79 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 110/117 | weighted_loss=1.5492 | 8.89 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 117/117 | weighted_loss=2.0565 | 8.98 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 en 0.24 min | weighted=1.8334 | hf_loss=1.7754 | bf_loss=1.8013 | val_loss=1.9430 | val_acc=35.46%
# Epoch 3: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 3/20 | Batch 1/117 | weighted_loss=1.4573 | 2.25 batch/s | ETA=0.9 min
# [CoTrain] Epoch 3/20 | Batch 10/117 | weighted_loss=1.5796 | 5.69 batch/s | ETA=0.3 min
# [CoTrain] Epoch 3/20 | Batch 20/117 | weighted_loss=1.7165 | 6.73 batch/s | ETA=0.2 min
# [CoTrain] Epoch 3/20 | Batch 30/117 | weighted_loss=1.6469 | 7.55 batch/s | ETA=0.2 min
# [CoTrain] Epoch 3/20 | Batch 40/117 | weighted_loss=1.7312 | 8.04 batch/s | ETA=0.2 min
# [CoTrain] Epoch 3/20 | Batch 50/117 | weighted_loss=1.8010 | 7.66 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 60/117 | weighted_loss=1.6611 | 7.92 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 70/117 | weighted_loss=1.3515 | 8.13 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 80/117 | weighted_loss=1.9352 | 8.26 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 90/117 | weighted_loss=1.6547 | 8.42 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 100/117 | weighted_loss=1.3708 | 8.46 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 110/117 | weighted_loss=1.6031 | 8.60 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 117/117 | weighted_loss=1.5370 | 8.24 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 en 0.26 min | weighted=1.6566 | hf_loss=1.5885 | bf_loss=1.6426 | val_loss=1.7238 | val_acc=40.55%
# Epoch 4: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 4/20 | Batch 1/117 | weighted_loss=1.2450 | 3.03 batch/s | ETA=0.6 min
# [CoTrain] Epoch 4/20 | Batch 10/117 | weighted_loss=1.6364 | 7.30 batch/s | ETA=0.2 min
# [CoTrain] Epoch 4/20 | Batch 20/117 | weighted_loss=1.2678 | 7.56 batch/s | ETA=0.2 min
# [CoTrain] Epoch 4/20 | Batch 30/117 | weighted_loss=1.4598 | 8.27 batch/s | ETA=0.2 min
# [CoTrain] Epoch 4/20 | Batch 40/117 | weighted_loss=1.6105 | 8.49 batch/s | ETA=0.2 min
# [CoTrain] Epoch 4/20 | Batch 50/117 | weighted_loss=1.3408 | 8.73 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 60/117 | weighted_loss=1.4754 | 8.10 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 70/117 | weighted_loss=1.5251 | 8.19 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 80/117 | weighted_loss=1.5433 | 8.41 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 90/117 | weighted_loss=1.2570 | 8.58 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 100/117 | weighted_loss=1.5109 | 8.70 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 110/117 | weighted_loss=1.3683 | 8.63 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 117/117 | weighted_loss=1.3527 | 8.64 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 en 0.24 min | weighted=1.4723 | hf_loss=1.3825 | bf_loss=1.4876 | val_loss=1.7061 | val_acc=45.44%
# Epoch 5: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 5/20 | Batch 1/117 | weighted_loss=1.5319 | 2.82 batch/s | ETA=0.7 min
# [CoTrain] Epoch 5/20 | Batch 10/117 | weighted_loss=1.2575 | 8.24 batch/s | ETA=0.2 min
# [CoTrain] Epoch 5/20 | Batch 20/117 | weighted_loss=1.2130 | 8.22 batch/s | ETA=0.2 min
# [CoTrain] Epoch 5/20 | Batch 30/117 | weighted_loss=1.2642 | 8.55 batch/s | ETA=0.2 min
# [CoTrain] Epoch 5/20 | Batch 40/117 | weighted_loss=1.3392 | 8.90 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 50/117 | weighted_loss=1.4972 | 8.91 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 60/117 | weighted_loss=1.6465 | 9.08 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 70/117 | weighted_loss=1.4877 | 9.21 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 80/117 | weighted_loss=1.8358 | 9.03 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 90/117 | weighted_loss=1.1326 | 9.03 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 100/117 | weighted_loss=1.6198 | 8.87 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 110/117 | weighted_loss=1.6278 | 8.87 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 117/117 | weighted_loss=1.2988 | 8.97 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 en 0.24 min | weighted=1.3350 | hf_loss=1.2400 | bf_loss=1.3620 | val_loss=1.3207 | val_acc=55.63%
# Epoch 6: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 6/20 | Batch 1/117 | weighted_loss=1.1314 | 2.83 batch/s | ETA=0.7 min
# [CoTrain] Epoch 6/20 | Batch 10/117 | weighted_loss=1.2584 | 7.59 batch/s | ETA=0.2 min
# [CoTrain] Epoch 6/20 | Batch 20/117 | weighted_loss=1.3304 | 7.19 batch/s | ETA=0.2 min
# [CoTrain] Epoch 6/20 | Batch 30/117 | weighted_loss=1.2066 | 7.94 batch/s | ETA=0.2 min
# [CoTrain] Epoch 6/20 | Batch 40/117 | weighted_loss=1.3091 | 8.16 batch/s | ETA=0.2 min
# [CoTrain] Epoch 6/20 | Batch 50/117 | weighted_loss=1.1218 | 8.46 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 60/117 | weighted_loss=1.4846 | 8.50 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 70/117 | weighted_loss=1.0265 | 8.71 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 80/117 | weighted_loss=0.7738 | 8.88 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 90/117 | weighted_loss=1.1497 | 8.84 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 100/117 | weighted_loss=1.1763 | 8.75 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 110/117 | weighted_loss=1.3523 | 8.86 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 117/117 | weighted_loss=1.0830 | 8.98 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 en 0.24 min | weighted=1.2473 | hf_loss=1.1130 | bf_loss=1.3158 | val_loss=1.3587 | val_acc=52.87%
# Epoch 7: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 7/20 | Batch 1/117 | weighted_loss=1.1779 | 2.87 batch/s | ETA=0.7 min
# [CoTrain] Epoch 7/20 | Batch 10/117 | weighted_loss=1.0258 | 5.77 batch/s | ETA=0.3 min
# [CoTrain] Epoch 7/20 | Batch 20/117 | weighted_loss=1.0370 | 7.35 batch/s | ETA=0.2 min
# [CoTrain] Epoch 7/20 | Batch 30/117 | weighted_loss=1.1670 | 8.13 batch/s | ETA=0.2 min
# [CoTrain] Epoch 7/20 | Batch 40/117 | weighted_loss=1.4385 | 7.87 batch/s | ETA=0.2 min
# [CoTrain] Epoch 7/20 | Batch 50/117 | weighted_loss=1.1808 | 8.27 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 60/117 | weighted_loss=1.0261 | 8.53 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 70/117 | weighted_loss=1.2448 | 8.74 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 80/117 | weighted_loss=0.8961 | 8.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 90/117 | weighted_loss=0.9995 | 8.79 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 100/117 | weighted_loss=1.1358 | 8.59 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 110/117 | weighted_loss=1.0280 | 8.64 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 117/117 | weighted_loss=1.1362 | 8.52 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 en 0.25 min | weighted=1.1547 | hf_loss=1.0026 | bf_loss=1.2446 | val_loss=1.4931 | val_acc=46.71%
# Epoch 8: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 8/20 | Batch 1/117 | weighted_loss=1.4011 | 2.78 batch/s | ETA=0.7 min
# [CoTrain] Epoch 8/20 | Batch 10/117 | weighted_loss=0.9609 | 8.21 batch/s | ETA=0.2 min
# [CoTrain] Epoch 8/20 | Batch 20/117 | weighted_loss=1.2197 | 8.38 batch/s | ETA=0.2 min
# [CoTrain] Epoch 8/20 | Batch 30/117 | weighted_loss=1.0366 | 7.75 batch/s | ETA=0.2 min
# [CoTrain] Epoch 8/20 | Batch 40/117 | weighted_loss=0.9720 | 8.22 batch/s | ETA=0.2 min
# [CoTrain] Epoch 8/20 | Batch 50/117 | weighted_loss=1.1279 | 7.92 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 60/117 | weighted_loss=1.0967 | 7.94 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 70/117 | weighted_loss=0.8478 | 8.21 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 80/117 | weighted_loss=1.0531 | 8.40 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 90/117 | weighted_loss=1.2419 | 8.02 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 100/117 | weighted_loss=1.2438 | 8.14 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 110/117 | weighted_loss=1.2699 | 8.07 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 117/117 | weighted_loss=1.2954 | 8.19 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 en 0.26 min | weighted=1.0898 | hf_loss=0.9145 | bf_loss=1.2049 | val_loss=1.8227 | val_acc=50.11%
# Epoch 9: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 9/20 | Batch 1/117 | weighted_loss=0.8579 | 2.89 batch/s | ETA=0.7 min
# [CoTrain] Epoch 9/20 | Batch 10/117 | weighted_loss=1.1306 | 8.12 batch/s | ETA=0.2 min
# [CoTrain] Epoch 9/20 | Batch 20/117 | weighted_loss=0.7319 | 8.95 batch/s | ETA=0.2 min
# [CoTrain] Epoch 9/20 | Batch 30/117 | weighted_loss=0.9218 | 7.95 batch/s | ETA=0.2 min
# [CoTrain] Epoch 9/20 | Batch 40/117 | weighted_loss=0.8571 | 7.85 batch/s | ETA=0.2 min
# [CoTrain] Epoch 9/20 | Batch 50/117 | weighted_loss=1.0007 | 7.79 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 60/117 | weighted_loss=0.9948 | 7.99 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 70/117 | weighted_loss=1.0172 | 8.25 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 80/117 | weighted_loss=1.0198 | 8.47 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 90/117 | weighted_loss=1.0880 | 8.26 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 100/117 | weighted_loss=0.9290 | 8.30 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 110/117 | weighted_loss=1.3191 | 8.34 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 117/117 | weighted_loss=1.1799 | 8.41 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 en 0.25 min | weighted=0.9855 | hf_loss=0.7782 | bf_loss=1.1360 | val_loss=1.2338 | val_acc=59.02%
# Epoch 10: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 10/20 | Batch 1/117 | weighted_loss=0.8053 | 2.92 batch/s | ETA=0.7 min
# [CoTrain] Epoch 10/20 | Batch 10/117 | weighted_loss=0.9786 | 6.77 batch/s | ETA=0.3 min
# [CoTrain] Epoch 10/20 | Batch 20/117 | weighted_loss=0.7615 | 7.70 batch/s | ETA=0.2 min
# [CoTrain] Epoch 10/20 | Batch 30/117 | weighted_loss=0.8660 | 8.38 batch/s | ETA=0.2 min
# [CoTrain] Epoch 10/20 | Batch 40/117 | weighted_loss=0.9319 | 8.35 batch/s | ETA=0.2 min
# [CoTrain] Epoch 10/20 | Batch 50/117 | weighted_loss=0.8441 | 8.65 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 60/117 | weighted_loss=0.7290 | 8.71 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 70/117 | weighted_loss=0.8918 | 8.87 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 80/117 | weighted_loss=1.2475 | 8.96 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 90/117 | weighted_loss=0.7932 | 9.08 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 100/117 | weighted_loss=1.0466 | 9.03 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 110/117 | weighted_loss=0.9426 | 8.67 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 117/117 | weighted_loss=1.2588 | 8.63 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 en 0.24 min | weighted=0.9090 | hf_loss=0.6599 | bf_loss=1.1031 | val_loss=1.1802 | val_acc=59.87%
# Epoch 11: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 11/20 | Batch 1/117 | weighted_loss=1.0364 | 2.95 batch/s | ETA=0.7 min
# [CoTrain] Epoch 11/20 | Batch 10/117 | weighted_loss=0.7832 | 7.22 batch/s | ETA=0.2 min
# [CoTrain] Epoch 11/20 | Batch 20/117 | weighted_loss=0.7817 | 8.37 batch/s | ETA=0.2 min
# [CoTrain] Epoch 11/20 | Batch 30/117 | weighted_loss=1.1037 | 8.96 batch/s | ETA=0.2 min
# [CoTrain] Epoch 11/20 | Batch 40/117 | weighted_loss=0.6975 | 8.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 50/117 | weighted_loss=1.0057 | 9.16 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 60/117 | weighted_loss=0.9367 | 8.74 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 70/117 | weighted_loss=0.8069 | 8.91 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 80/117 | weighted_loss=0.9751 | 9.05 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 90/117 | weighted_loss=0.6465 | 9.15 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 100/117 | weighted_loss=0.9153 | 9.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 110/117 | weighted_loss=1.0493 | 9.16 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 117/117 | weighted_loss=0.9130 | 9.26 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 en 0.23 min | weighted=0.8434 | hf_loss=0.5548 | bf_loss=1.0780 | val_loss=1.5762 | val_acc=53.50%
# Epoch 12: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 12/20 | Batch 1/117 | weighted_loss=0.7147 | 2.85 batch/s | ETA=0.7 min
# [CoTrain] Epoch 12/20 | Batch 10/117 | weighted_loss=1.0554 | 7.45 batch/s | ETA=0.2 min
# [CoTrain] Epoch 12/20 | Batch 20/117 | weighted_loss=0.8409 | 8.58 batch/s | ETA=0.2 min
# [CoTrain] Epoch 12/20 | Batch 30/117 | weighted_loss=1.0185 | 8.23 batch/s | ETA=0.2 min
# [CoTrain] Epoch 12/20 | Batch 40/117 | weighted_loss=0.6717 | 8.59 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 50/117 | weighted_loss=0.6373 | 8.45 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 60/117 | weighted_loss=0.7856 | 8.72 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 70/117 | weighted_loss=0.7535 | 8.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 80/117 | weighted_loss=1.0536 | 8.68 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 90/117 | weighted_loss=0.7659 | 8.70 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 100/117 | weighted_loss=0.8559 | 8.66 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 110/117 | weighted_loss=0.6382 | 8.80 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 117/117 | weighted_loss=0.8884 | 8.92 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 en 0.24 min | weighted=0.7523 | hf_loss=0.4509 | bf_loss=1.0034 | val_loss=1.2598 | val_acc=57.75%
# Epoch 13: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 13/20 | Batch 1/117 | weighted_loss=0.8038 | 2.84 batch/s | ETA=0.7 min
# [CoTrain] Epoch 13/20 | Batch 10/117 | weighted_loss=0.4565 | 7.49 batch/s | ETA=0.2 min
# [CoTrain] Epoch 13/20 | Batch 20/117 | weighted_loss=0.3695 | 7.63 batch/s | ETA=0.2 min
# [CoTrain] Epoch 13/20 | Batch 30/117 | weighted_loss=0.5757 | 8.35 batch/s | ETA=0.2 min
# [CoTrain] Epoch 13/20 | Batch 40/117 | weighted_loss=0.7236 | 8.69 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 50/117 | weighted_loss=0.5930 | 8.77 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 60/117 | weighted_loss=0.7197 | 8.30 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 70/117 | weighted_loss=0.4073 | 8.05 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 80/117 | weighted_loss=0.5699 | 8.28 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 90/117 | weighted_loss=0.8701 | 8.32 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 100/117 | weighted_loss=0.8313 | 8.48 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 110/117 | weighted_loss=0.7298 | 8.62 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 117/117 | weighted_loss=0.5967 | 8.67 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 en 0.24 min | weighted=0.6501 | hf_loss=0.3179 | bf_loss=0.9356 | val_loss=1.2819 | val_acc=58.81%
# Epoch 14: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 14/20 | Batch 1/117 | weighted_loss=0.5264 | 2.87 batch/s | ETA=0.7 min
# [CoTrain] Epoch 14/20 | Batch 10/117 | weighted_loss=0.7106 | 7.42 batch/s | ETA=0.2 min
# [CoTrain] Epoch 14/20 | Batch 20/117 | weighted_loss=0.6131 | 8.04 batch/s | ETA=0.2 min
# [CoTrain] Epoch 14/20 | Batch 30/117 | weighted_loss=0.4386 | 8.24 batch/s | ETA=0.2 min
# [CoTrain] Epoch 14/20 | Batch 40/117 | weighted_loss=0.3958 | 8.65 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 50/117 | weighted_loss=0.6956 | 8.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 60/117 | weighted_loss=0.5954 | 8.34 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 70/117 | weighted_loss=0.6777 | 8.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 80/117 | weighted_loss=0.5749 | 8.60 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 90/117 | weighted_loss=0.5824 | 8.75 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 100/117 | weighted_loss=0.5666 | 8.89 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 110/117 | weighted_loss=0.6041 | 9.00 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 117/117 | weighted_loss=0.5359 | 9.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 en 0.24 min | weighted=0.6176 | hf_loss=0.2593 | bf_loss=0.9295 | val_loss=1.5286 | val_acc=56.48%
# Epoch 15: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 15/20 | Batch 1/117 | weighted_loss=0.4777 | 3.00 batch/s | ETA=0.6 min
# [CoTrain] Epoch 15/20 | Batch 10/117 | weighted_loss=0.4667 | 7.12 batch/s | ETA=0.3 min
# [CoTrain] Epoch 15/20 | Batch 20/117 | weighted_loss=0.5523 | 8.09 batch/s | ETA=0.2 min
# [CoTrain] Epoch 15/20 | Batch 30/117 | weighted_loss=0.4978 | 8.35 batch/s | ETA=0.2 min
# [CoTrain] Epoch 15/20 | Batch 40/117 | weighted_loss=0.6327 | 8.70 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 50/117 | weighted_loss=0.5278 | 8.99 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 60/117 | weighted_loss=0.7229 | 8.81 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 70/117 | weighted_loss=0.6206 | 8.92 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 80/117 | weighted_loss=0.6013 | 9.06 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 90/117 | weighted_loss=0.5629 | 9.02 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 100/117 | weighted_loss=0.6123 | 9.01 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 110/117 | weighted_loss=0.5457 | 8.97 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 117/117 | weighted_loss=0.7071 | 9.06 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 en 0.23 min | weighted=0.5372 | hf_loss=0.1844 | bf_loss=0.8476 | val_loss=1.3612 | val_acc=60.51%
# Epoch 16: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 16/20 | Batch 1/117 | weighted_loss=0.6176 | 2.83 batch/s | ETA=0.7 min
# [CoTrain] Epoch 16/20 | Batch 10/117 | weighted_loss=0.4766 | 8.02 batch/s | ETA=0.2 min
# [CoTrain] Epoch 16/20 | Batch 20/117 | weighted_loss=0.6161 | 8.61 batch/s | ETA=0.2 min
# [CoTrain] Epoch 16/20 | Batch 30/117 | weighted_loss=0.3630 | 8.37 batch/s | ETA=0.2 min
# [CoTrain] Epoch 16/20 | Batch 40/117 | weighted_loss=0.5472 | 8.43 batch/s | ETA=0.2 min
# [CoTrain] Epoch 16/20 | Batch 50/117 | weighted_loss=0.4713 | 8.52 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 60/117 | weighted_loss=0.5799 | 8.42 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 70/117 | weighted_loss=0.5148 | 8.66 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 80/117 | weighted_loss=0.6779 | 8.58 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 90/117 | weighted_loss=0.5661 | 8.76 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 100/117 | weighted_loss=0.4858 | 8.90 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 110/117 | weighted_loss=0.3808 | 9.02 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 117/117 | weighted_loss=0.5970 | 9.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 en 0.23 min | weighted=0.5196 | hf_loss=0.1702 | bf_loss=0.8277 | val_loss=1.2534 | val_acc=64.54%
# Epoch 17: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 17/20 | Batch 1/117 | weighted_loss=0.2594 | 2.81 batch/s | ETA=0.7 min
# [CoTrain] Epoch 17/20 | Batch 10/117 | weighted_loss=0.2960 | 8.28 batch/s | ETA=0.2 min
# [CoTrain] Epoch 17/20 | Batch 20/117 | weighted_loss=0.4542 | 8.23 batch/s | ETA=0.2 min
# [CoTrain] Epoch 17/20 | Batch 30/117 | weighted_loss=0.4010 | 8.32 batch/s | ETA=0.2 min
# [CoTrain] Epoch 17/20 | Batch 40/117 | weighted_loss=0.3257 | 8.72 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 50/117 | weighted_loss=0.3013 | 8.97 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 60/117 | weighted_loss=0.4557 | 8.96 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 70/117 | weighted_loss=0.4094 | 8.99 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 80/117 | weighted_loss=0.6784 | 8.88 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 90/117 | weighted_loss=0.3718 | 9.03 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 100/117 | weighted_loss=0.5151 | 9.10 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 110/117 | weighted_loss=0.3970 | 8.83 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 117/117 | weighted_loss=0.4412 | 8.94 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 en 0.24 min | weighted=0.4512 | hf_loss=0.1165 | bf_loss=0.7484 | val_loss=1.9145 | val_acc=54.56%
# Epoch 18: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 18/20 | Batch 1/117 | weighted_loss=0.4644 | 2.95 batch/s | ETA=0.7 min
# [CoTrain] Epoch 18/20 | Batch 10/117 | weighted_loss=0.4916 | 7.25 batch/s | ETA=0.2 min
# [CoTrain] Epoch 18/20 | Batch 20/117 | weighted_loss=0.3745 | 8.48 batch/s | ETA=0.2 min
# [CoTrain] Epoch 18/20 | Batch 30/117 | weighted_loss=0.3554 | 7.86 batch/s | ETA=0.2 min
# [CoTrain] Epoch 18/20 | Batch 40/117 | weighted_loss=0.5461 | 8.33 batch/s | ETA=0.2 min
# [CoTrain] Epoch 18/20 | Batch 50/117 | weighted_loss=0.4282 | 8.25 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 60/117 | weighted_loss=0.4305 | 8.35 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 70/117 | weighted_loss=0.4535 | 8.02 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 80/117 | weighted_loss=0.4547 | 8.16 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 90/117 | weighted_loss=0.3233 | 8.31 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 100/117 | weighted_loss=0.4750 | 8.24 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 110/117 | weighted_loss=0.3546 | 8.12 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 117/117 | weighted_loss=0.4258 | 8.18 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 en 0.26 min | weighted=0.4279 | hf_loss=0.1063 | bf_loss=0.7138 | val_loss=1.4005 | val_acc=61.78%
# Epoch 19: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 19/20 | Batch 1/117 | weighted_loss=0.5021 | 2.83 batch/s | ETA=0.7 min
# [CoTrain] Epoch 19/20 | Batch 10/117 | weighted_loss=0.3841 | 7.94 batch/s | ETA=0.2 min
# [CoTrain] Epoch 19/20 | Batch 20/117 | weighted_loss=0.3944 | 8.94 batch/s | ETA=0.2 min
# [CoTrain] Epoch 19/20 | Batch 30/117 | weighted_loss=0.3840 | 9.30 batch/s | ETA=0.2 min
# [CoTrain] Epoch 19/20 | Batch 40/117 | weighted_loss=0.5487 | 9.07 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 50/117 | weighted_loss=0.3666 | 9.23 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 60/117 | weighted_loss=0.3477 | 9.05 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 70/117 | weighted_loss=0.6594 | 9.19 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 80/117 | weighted_loss=0.3075 | 9.02 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 90/117 | weighted_loss=0.4134 | 8.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 100/117 | weighted_loss=0.4974 | 9.04 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 110/117 | weighted_loss=0.3080 | 8.74 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 117/117 | weighted_loss=0.2777 | 8.78 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 en 0.24 min | weighted=0.4057 | hf_loss=0.0939 | bf_loss=0.6833 | val_loss=1.0904 | val_acc=67.73%
# Epoch 20: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 20/20 | Batch 1/117 | weighted_loss=0.2924 | 2.90 batch/s | ETA=0.7 min
# [CoTrain] Epoch 20/20 | Batch 10/117 | weighted_loss=0.2643 | 8.31 batch/s | ETA=0.2 min
# [CoTrain] Epoch 20/20 | Batch 20/117 | weighted_loss=0.2132 | 7.90 batch/s | ETA=0.2 min
# [CoTrain] Epoch 20/20 | Batch 30/117 | weighted_loss=0.3013 | 7.64 batch/s | ETA=0.2 min
# [CoTrain] Epoch 20/20 | Batch 40/117 | weighted_loss=0.3793 | 8.08 batch/s | ETA=0.2 min
# [CoTrain] Epoch 20/20 | Batch 50/117 | weighted_loss=0.3545 | 8.33 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 60/117 | weighted_loss=0.2856 | 8.47 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 70/117 | weighted_loss=0.5524 | 8.68 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 80/117 | weighted_loss=0.3585 | 8.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 90/117 | weighted_loss=0.3171 | 8.77 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 100/117 | weighted_loss=0.4541 | 8.79 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 110/117 | weighted_loss=0.5996 | 8.89 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 117/117 | weighted_loss=0.2501 | 8.88 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 en 0.24 min | weighted=0.3654 | hf_loss=0.0697 | bf_loss=0.6295 | val_loss=1.0922 | val_acc=69.85%
# Entrainement termine en 5.10 min

# %% [markdown]
# ## 6) Evaluation finale, cout, sauvegarde et visualisation

# %%
criterion = nn.CrossEntropyLoss()
test_hf_loss, test_hf_acc = evaluate(model, loader_test_hf, criterion)
test_bf_loss, test_bf_acc = evaluate(model, loader_test_bf, criterion)
test_mix_acc = (test_hf_acc + test_bf_acc) / 2.0

hf_seen_per_epoch = mixed_batch_sampler.hf_per_batch * len(loader_mixed_train)
bf_seen_per_epoch = mixed_batch_sampler.bf_per_batch * len(loader_mixed_train)
hf_seen_total = hf_seen_per_epoch * EPOCHS
bf_seen_total = bf_seen_per_epoch * EPOCHS
total_cost = hf_seen_total * COST_HF + bf_seen_total * COST_BF

results = {
    'strategy': 'cotraining_batch_reweighting',
    'pipeline': 'mixed_batches_with_domain_weighted_loss',
    'epochs': EPOCHS,
    'lr': LR,
    'batch_size': BATCH_SIZE,
    'hf_batch_ratio': HF_BATCH_RATIO,
    'hf_per_batch': mixed_batch_sampler.hf_per_batch,
    'bf_per_batch': mixed_batch_sampler.bf_per_batch,
    'hf_loss_weight': HF_LOSS_WEIGHT,
    'bf_loss_weight': BF_LOSS_WEIGHT,
    'hf_seen_total_samples': int(hf_seen_total),
    'bf_seen_total_samples': int(bf_seen_total),
    'total_cost_CA': int(total_cost),
    'training_time_min': float(training_time_min),
    'test_hf_loss': float(test_hf_loss),
    'test_bf_loss': float(test_bf_loss),
    'accuracy_HF': float(test_hf_acc),
    'accuracy_BF': float(test_bf_acc),
    'accuracy_Mixte': float(test_mix_acc)
}

json_path = os.path.join(RESULTS_DIR, 'results_strategy2_cotraining_reweighting.json')
pth_path = os.path.join(RESULTS_DIR, 'model_strategy2_cotraining_reweighting.pth')
png_path = os.path.join(RESULTS_DIR, 'strategy2_cotraining_reweighting_curves.png')

with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

torch.save(model.state_dict(), pth_path)

print('--- RESULTATS FINAUX ---')
print(f"Test HF    : {test_hf_acc:.2f}%")
print(f"Test BF    : {test_bf_acc:.2f}%")
print(f"Test Mixte : {test_mix_acc:.2f}%")
print(f"Cout total : {total_cost} CA")
print(f"Temps total: {training_time_min:.2f} min")
print('JSON sauve :', json_path)
print('Model sauve:', pth_path)

x = np.arange(1, EPOCHS + 1)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(x, history['train_weighted_loss'], marker='o', label='Train loss ponderee (HF/BF)')
axes[0].plot(x, history['val_loss'], marker='o', linestyle='--', label='Val loss HF')
axes[0].plot(x, history['train_hf_loss'], marker='o', alpha=0.7, label='Train HF loss (non ponderee)')
axes[0].plot(x, history['train_bf_loss'], marker='o', alpha=0.7, label='Train BF loss (non ponderee)')
axes[0].set_title('Evolution des losses - Strategie 2')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)
axes[0].legend(fontsize=8)

axes[1].plot(x, history['val_acc'], marker='o', color='tab:green', label='Val accuracy HF')
axes[1].set_title('Precision validation HF')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')
axes[1].grid(alpha=0.3)
axes[1].legend(fontsize=9)

plt.tight_layout()
plt.savefig(png_path, dpi=180, bbox_inches='tight')
plt.show()
print('Figure sauvee:', png_path)
# Out:
# --- RESULTATS FINAUX ---
# Test HF    : 70.12%
# Test BF    : 61.90%
# Test Mixte : 66.01%
# Cout total : 486720 CA
# Temps total: 5.10 min
# JSON sauve : /content/drive/MyDrive/UTBM_PF22/results/results_strategy2_cotraining_reweighting.json
# Model sauve: /content/drive/MyDrive/UTBM_PF22/results/model_strategy2_cotraining_reweighting.pth
# Figure sauvee: /content/drive/MyDrive/UTBM_PF22/results/strategy2_cotraining_reweighting_curves.png

# %% [markdown]
# ## 7) Comparaison optionnelle avec baselines et strategie 1

# %%
comparison_files = {
    'BL 1(HF)': 'results_baseline_HF.json',
    'BL 2(BF)': 'results_baseline_BF.json',
    'BL 3(MIXTE)': 'results_baseline_MIXTE.json',
    'Strategie 1(BF->HF)': 'results_strategy1_transfer_learning.json',
    'Strategie 2(CoTrain)': 'results_strategy2_cotraining_reweighting.json'
}

rows = []
for name, fn in comparison_files.items():
    p = os.path.join(RESULTS_DIR, fn)
    if os.path.exists(p):
        with open(p, 'r', encoding='utf-8') as f:
            d = json.load(f)
        rows.append((
            name,
            d.get('accuracy_HF', np.nan),
            d.get('accuracy_BF', np.nan),
            d.get('accuracy_Mixte', np.nan),
            d.get('total_cost_CA', np.nan),
            d.get('training_time_min', d.get('total_time_min', np.nan))
        ))

if not rows:
    print('Aucun fichier JSON trouve pour la comparaison.')
else:
    header = f"{'Modele':<25} {'HF%':>8} {'BF%':>8} {'Mixte%':>10} {'Cout(CA)':>12} {'Temps(min)':>12}"
    print(header)
    print('-' * len(header))
    for r in rows:
        print(f"{r[0]:<25} {r[1]:>8.2f} {r[2]:>8.2f} {r[3]:>10.2f} {r[4]:>12.0f} {r[5]:>12.2f}")
# Out:
# Modele                         HF%      BF%     Mixte%     Cout(CA)   Temps(min)
# --------------------------------------------------------------------------------
# BL 1(HF)                     56.20    35.16      45.68       470400          nan
# BL 2(BF)                     59.07    63.66      61.36       424260          nan
# BL 3(MIXTE)                  75.90    65.03      70.47       894660          nan
# Strategie 1(BF->HF)          78.84    57.65      68.25       400230         7.83
# Strategie 2(CoTrain)         70.12    61.90      66.01       486720         5.10
