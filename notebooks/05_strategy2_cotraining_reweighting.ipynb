# %% [markdown]
# # Partie 4 - Etape 2: Strategie 2 Co-training par Batch avec Ponderation
#
# Cette experience implemente un **co-training HF+BF simultane** avec deux mecanismes:
# - un **ratio fixe HF/BF par batch** via un batch sampler personnalise,
# - une **loss ponderee par domaine** qui donne plus d'importance aux echantillons HF.
#
# ## Objectif
# - Preserver une forte performance sur Test HF (objectif prioritaire).
# - Maintenir une robustesse raisonnable sur BF.
# - Evaluer le compromis performance / cout en CA.

# %%
import os
import json
import time
import random
import shutil

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split, Sampler
from torchvision import datasets, transforms, models
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt

try:
    import wandb
    _WANDB_AVAILABLE = True
except ImportError:
    _WANDB_AVAILABLE = False
    print("⚠️ wandb non installé : pip install wandb pour activer le tracking.")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.benchmark = True
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Appareil: {device}')
# Out:
# Appareil: cuda

# %% [markdown]
# ## 1) Montage Drive et chemins de travail
# Continuite avec les notebooks precedents: SSD local prioritaire, puis fallback Drive.

# %%
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive', force_remount=True)

    local_base = '/content/processed_multifidelity'
    zip_source = '/content/drive/MyDrive/UTBM_PF22/datasets/Animals-10/dataset_multifidelity.zip'
    drive_base_candidates = [
        '/content/drive/MyDrive/UTBM_PF22/datasets/Animals-10/processed_multifidelity',
        '/content/drive/MyDrive/UTBM_PF22/results/datasets/Animals-10/processed_multifidelity',
    ]

    if os.path.exists(local_base):
        print('Dataset deja present sur SSD local, reutilisation.')
        BASE_DIR = local_base
    else:
        if os.path.exists(zip_source):
            print('Extraction du zip dataset vers SSD local...')
            start = time.time()
            shutil.copy2(zip_source, '/content/dataset_multifidelity.zip')
            import zipfile
            with zipfile.ZipFile('/content/dataset_multifidelity.zip', 'r') as zip_ref:
                zip_ref.extractall('/content/')
            os.remove('/content/dataset_multifidelity.zip')
            print(f'Dataset extrait sur SSD en {time.time()-start:.2f}s')
            BASE_DIR = local_base if os.path.exists(local_base) else None
        else:
            BASE_DIR = None

        if BASE_DIR is None:
            drive_base = next((p for p in drive_base_candidates if os.path.exists(p)), None)
            if drive_base is None:
                raise FileNotFoundError(
                    'Aucun dataset trouve. Chemins testes: '
                    + ' | '.join([zip_source] + drive_base_candidates)
                )
            print('SSD indisponible, fallback vers le dossier Drive deja prepare.')
            BASE_DIR = drive_base

    RESULTS_DIR = '/content/drive/MyDrive/UTBM_PF22/results'
else:
    candidate_base_dirs = [
        '../data/processed_multifidelity',
        './data/processed_multifidelity',
        'data/processed_multifidelity',
    ]
    BASE_DIR = next((p for p in candidate_base_dirs if os.path.exists(p)), None)
    if BASE_DIR is None:
        raise FileNotFoundError(
            'Aucun dossier processed_multifidelity trouve. Chemins testes: '
            + ' | '.join(candidate_base_dirs)
        )
    RESULTS_DIR = '../results'

os.makedirs(RESULTS_DIR, exist_ok=True)
print('BASE_DIR selectionne =', BASE_DIR)
print('RESULTS_DIR         =', RESULTS_DIR)
# Out:
# Mounted at /content/drive
# Dataset deja present sur SSD local, reutilisation.
# BASE_DIR selectionne = /content/processed_multifidelity
# RESULTS_DIR         = /content/drive/MyDrive/UTBM_PF22/results

# %% [markdown]
# ## 2) Configuration, datasets et transforms

# %%
COST_HF = 10
COST_BF = 1
BATCH_SIZE = 64
NUM_WORKERS = 2 if '/content/processed_multifidelity' in str(BASE_DIR) else 0
EPOCHS = 20
LR = 1e-3
HF_TRAIN_RATIO = 0.8
HF_BATCH_RATIO = 0.25
HF_LOSS_WEIGHT = 2.0
BF_LOSS_WEIGHT = 0.7

class AddDegradationTransform:
    """Degrade un tenseur image pour simuler le domaine BF."""
    def __call__(self, img_tensor):
        h, w = img_tensor.shape[1], img_tensor.shape[2]
        img_degraded = transforms.functional.resize(img_tensor, (64, 64), antialias=True)
        img_degraded = transforms.functional.resize(img_degraded, (h, w), antialias=True)
        noise = torch.randn_like(img_degraded) * 0.15
        img_noisy = img_degraded + noise
        return torch.clamp(img_noisy, 0, 1)

transform_standard = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_bf_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    AddDegradationTransform(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

required_dirs = [
    os.path.join(BASE_DIR, 'train', 'HF'),
    os.path.join(BASE_DIR, 'train', 'BF'),
    os.path.join(BASE_DIR, 'test'),
]
missing = [p for p in required_dirs if not os.path.isdir(p)]
if missing:
    raise FileNotFoundError(
        'Structure dataset invalide. Dossiers manquants: ' + ' | '.join(missing)
    )

dataset_hf_full = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/HF'), transform=transform_standard)
dataset_bf_train = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/BF'), transform=transform_standard)
dataset_test_hf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_standard)
dataset_test_bf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_bf_test)

hf_train_size = int(HF_TRAIN_RATIO * len(dataset_hf_full))
hf_val_size = len(dataset_hf_full) - hf_train_size
dataset_hf_train, dataset_hf_val = random_split(
    dataset_hf_full,
    [hf_train_size, hf_val_size],
    generator=torch.Generator().manual_seed(SEED)
)

loader_hf_val = DataLoader(dataset_hf_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_hf = DataLoader(dataset_test_hf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_bf = DataLoader(dataset_test_bf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f'HF train: {len(dataset_hf_train)} | HF val: {len(dataset_hf_val)}')
print(f'BF train: {len(dataset_bf_train)} | Test HF/BF: {len(dataset_test_hf)}')
print(f'NUM_WORKERS utilise: {NUM_WORKERS}')
# Out:
# HF train: 1881 | HF val: 471
# BF train: 21213 | Test HF/BF: 2614
# NUM_WORKERS utilise: 2

# %% [markdown]
# ## 3) Batch sampler mixte HF/BF (ratio fixe par batch)
# On construit un dataset concatene avec un indicateur de domaine, puis un sampler qui force une composition fixe de chaque lot.

# %%
class DomainLabeledConcatDataset(Dataset):
    def __init__(self, hf_dataset, bf_dataset):
        self.hf_dataset = hf_dataset
        self.bf_dataset = bf_dataset
        self.hf_len = len(hf_dataset)
        self.bf_len = len(bf_dataset)

    def __len__(self):
        return self.hf_len + self.bf_len

    def __getitem__(self, idx):
        if idx < self.hf_len:
            x, y = self.hf_dataset[idx]
            domain = 1
        else:
            x, y = self.bf_dataset[idx - self.hf_len]
            domain = 0
        return x, y, domain

class MixedBatchSampler(Sampler):
    def __init__(self, hf_indices, bf_indices, batch_size, hf_ratio=0.25, seed=42, drop_last=True):
        self.hf_indices = list(hf_indices)
        self.bf_indices = list(bf_indices)
        self.batch_size = int(batch_size)
        self.hf_ratio = float(hf_ratio)
        self.drop_last = drop_last
        self.seed = int(seed)
        self.epoch = 0

        self.hf_per_batch = max(1, int(round(self.batch_size * self.hf_ratio)))
        self.bf_per_batch = self.batch_size - self.hf_per_batch
        if self.bf_per_batch <= 0:
            raise ValueError('hf_ratio trop grand: bf_per_batch <= 0')

        self.num_batches = min(
            len(self.hf_indices) // self.hf_per_batch,
            len(self.bf_indices) // self.bf_per_batch
        )
        if self.num_batches <= 0:
            raise ValueError('Pas assez de donnees pour former un seul batch mixte.')

    def __len__(self):
        return self.num_batches

    def set_epoch(self, epoch):
        self.epoch = int(epoch)

    def __iter__(self):
        g = torch.Generator()
        g.manual_seed(self.seed + self.epoch)

        hf_perm = torch.randperm(len(self.hf_indices), generator=g).tolist()
        bf_perm = torch.randperm(len(self.bf_indices), generator=g).tolist()

        for b in range(self.num_batches):
            h0 = b * self.hf_per_batch
            h1 = h0 + self.hf_per_batch
            b0 = b * self.bf_per_batch
            b1 = b0 + self.bf_per_batch

            batch_hf = [self.hf_indices[i] for i in hf_perm[h0:h1]]
            batch_bf = [self.bf_indices[i] for i in bf_perm[b0:b1]]
            batch = batch_hf + batch_bf

            order = torch.randperm(len(batch), generator=g).tolist()
            yield [batch[i] for i in order]

mixed_train_dataset = DomainLabeledConcatDataset(dataset_hf_train, dataset_bf_train)
hf_indices = list(range(len(dataset_hf_train)))
bf_offset = len(dataset_hf_train)
bf_indices = list(range(bf_offset, bf_offset + len(dataset_bf_train)))

mixed_batch_sampler = MixedBatchSampler(
    hf_indices=hf_indices,
    bf_indices=bf_indices,
    batch_size=BATCH_SIZE,
    hf_ratio=HF_BATCH_RATIO,
    seed=SEED,
    drop_last=True
)

loader_mixed_train = DataLoader(
    mixed_train_dataset,
    batch_sampler=mixed_batch_sampler,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

print(f'Batches/epoch: {len(loader_mixed_train)}')
print(f'Composition batch: HF={mixed_batch_sampler.hf_per_batch}, BF={mixed_batch_sampler.bf_per_batch}')
print(f'Ratio HF reel par batch: {mixed_batch_sampler.hf_per_batch / BATCH_SIZE:.3f}')
# Out:
# Batches/epoch: 117
# Composition batch: HF=16, BF=48
# Ratio HF reel par batch: 0.250

# %% [markdown]
# ## 4) Modele, loss ponderee et utilitaires

# %%
def create_model(num_classes=10):
    model = models.resnet18(weights=None)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)
            total_loss += loss.item() * x.size(0)
            total_correct += (logits.argmax(dim=1) == y).sum().item()
            total_samples += x.size(0)
    return total_loss / total_samples, 100.0 * total_correct / total_samples

def make_grad_scaler():
    try:
        return GradScaler('cuda', enabled=(device.type == 'cuda'))
    except TypeError:
        return GradScaler(enabled=(device.type == 'cuda'))

def train_cotraining_weighted(model, train_loader, sampler, val_loader, epochs, lr, hf_w, bf_w,
                              use_wandb=False, cost_per_epoch_CA=0):
    """Co-training HF/BF avec loss pondérée par domaine.

    Si `use_wandb=True`, logge à W&B à la fin de chaque epoch :
    weighted_loss / hf_loss / bf_loss / val_loss / val_acc / cumulative_cost_CA.
    """
    ce_none = nn.CrossEntropyLoss(reduction='none')
    ce_mean = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = make_grad_scaler()

    history = {
        'train_weighted_loss': [],
        'train_hf_loss': [],
        'train_bf_loss': [],
        'val_loss': [],
        'val_acc': []
    }

    print(f'Loss weights utilises: HF={hf_w} | BF={bf_w}')
    print(f'Ratio batch cible: HF={sampler.hf_per_batch}/{BATCH_SIZE} | BF={sampler.bf_per_batch}/{BATCH_SIZE}')

    for epoch in range(1, epochs + 1):
        sampler.set_epoch(epoch)
        model.train()

        total_weighted = 0.0
        total_samples = 0
        hf_loss_sum = 0.0
        hf_count = 0
        bf_loss_sum = 0.0
        bf_count = 0

        epoch_start = time.time()
        log_every = 10

        for batch_idx, (x, y, domain) in enumerate(train_loader, start=1):
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            domain = domain.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                per_sample_loss = ce_none(logits, y)
                sample_weights = torch.where(
                    domain == 1,
                    torch.full_like(per_sample_loss, float(hf_w)),
                    torch.full_like(per_sample_loss, float(bf_w))
                )
                weighted_loss = (per_sample_loss * sample_weights).mean()

            scaler.scale(weighted_loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_weighted += weighted_loss.item() * x.size(0)
            total_samples += x.size(0)

            hf_mask = (domain == 1)
            bf_mask = (domain == 0)
            if hf_mask.any():
                hf_loss_sum += per_sample_loss[hf_mask].detach().sum().item()
                hf_count += int(hf_mask.sum().item())
            if bf_mask.any():
                bf_loss_sum += per_sample_loss[bf_mask].detach().sum().item()
                bf_count += int(bf_mask.sum().item())

            if batch_idx == 1:
                n_hf_batch = int(hf_mask.sum().item())
                n_bf_batch = int(bf_mask.sum().item())
                print(f'Epoch {epoch}: composition premier batch HF={n_hf_batch}, BF={n_bf_batch}')

            if batch_idx % log_every == 0 or batch_idx == 1 or batch_idx == len(train_loader):
                elapsed = time.time() - epoch_start
                bps = batch_idx / elapsed if elapsed > 0 else 0.0
                eta_sec = (len(train_loader) - batch_idx) / bps if bps > 0 else 0.0
                print(
                    f'[CoTrain] Epoch {epoch}/{epochs} | Batch {batch_idx}/{len(train_loader)} | '
                    f'weighted_loss={weighted_loss.item():.4f} | {bps:.2f} batch/s | ETA={eta_sec/60:.1f} min'
                )

        train_weighted_loss = total_weighted / max(1, total_samples)
        train_hf_loss = hf_loss_sum / max(1, hf_count)
        train_bf_loss = bf_loss_sum / max(1, bf_count)
        val_loss, val_acc = evaluate(model, val_loader, ce_mean)
        epoch_min = (time.time() - epoch_start) / 60.0

        history['train_weighted_loss'].append(train_weighted_loss)
        history['train_hf_loss'].append(train_hf_loss)
        history['train_bf_loss'].append(train_bf_loss)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(
            f'[CoTrain] Epoch {epoch}/{epochs} en {epoch_min:.2f} min | '
            f'weighted={train_weighted_loss:.4f} | hf_loss={train_hf_loss:.4f} | '
            f'bf_loss={train_bf_loss:.4f} | val_loss={val_loss:.4f} | val_acc={val_acc:.2f}%'
        )

        if use_wandb and _WANDB_AVAILABLE:
            wandb.log({
                "epoch": epoch,
                "train/weighted_loss": train_weighted_loss,
                "train/hf_loss": train_hf_loss,
                "train/bf_loss": train_bf_loss,
                "val/loss": val_loss,
                "val/accuracy": val_acc,
                "cumulative_cost_CA": cost_per_epoch_CA * epoch,
                "epoch_time_min": epoch_min,
            })

    return history

# %% [markdown]
# ## 5) Execution Strategie 2 (co-training pondéré)

# %%
# --- Configuration W&B ---
USE_WANDB = True
DATASET_NAME = "Animals-10"
WANDB_PROJECT = "PF22-MultiFidelity"
WANDB_RUN_NAME = "Strategie2_Reweighting"

# Coût par epoch : (HF par batch * COST_HF + BF par batch * COST_BF) * nb_batches
cost_per_epoch_cotrain = (
    mixed_batch_sampler.hf_per_batch * COST_HF
    + mixed_batch_sampler.bf_per_batch * COST_BF
) * len(loader_mixed_train)

if USE_WANDB and _WANDB_AVAILABLE:
    wandb.init(
        project=WANDB_PROJECT,
        name=WANDB_RUN_NAME,
        tags=["strategy2", "cotraining", "reweighting", DATASET_NAME],
        reinit=True,
        config={
            "strategy": "cotraining_batch_reweighting",
            "pipeline": "mixed_batches_with_domain_weighted_loss",
            "dataset": DATASET_NAME,
            "architecture": "resnet18",
            "weights_init": "from_scratch",
            "num_classes": 10,
            "input_size": 224,
            "epochs": EPOCHS,
            "batch_size": BATCH_SIZE,
            "learning_rate": LR,
            "hf_train_ratio": HF_TRAIN_RATIO,
            "hf_batch_ratio": HF_BATCH_RATIO,
            "hf_per_batch": mixed_batch_sampler.hf_per_batch,
            "bf_per_batch": mixed_batch_sampler.bf_per_batch,
            "hf_loss_weight": HF_LOSS_WEIGHT,
            "bf_loss_weight": BF_LOSS_WEIGHT,
            "optimizer": "Adam",
            "loss": "CrossEntropyLoss (per-sample, domain-weighted)",
            "amp_fp16": True,
            "cost_HF_per_image": COST_HF,
            "cost_BF_per_image": COST_BF,
            "cost_per_epoch_CA": int(cost_per_epoch_cotrain),
            "total_cost_CA_planned": int(cost_per_epoch_cotrain * EPOCHS),
            "train_size_HF": len(dataset_hf_train),
            "train_size_BF": len(dataset_bf_train),
            "val_size_HF": len(dataset_hf_val),
            "test_size": len(dataset_test_hf),
            "batches_per_epoch": len(loader_mixed_train),
        }
    )

model = create_model(num_classes=10)
print('Modele initialise:', model.__class__.__name__)

start_train = time.time()
history = train_cotraining_weighted(
    model=model,
    train_loader=loader_mixed_train,
    sampler=mixed_batch_sampler,
    val_loader=loader_hf_val,
    epochs=EPOCHS,
    lr=LR,
    hf_w=HF_LOSS_WEIGHT,
    bf_w=BF_LOSS_WEIGHT,
    use_wandb=USE_WANDB,
    cost_per_epoch_CA=int(cost_per_epoch_cotrain),
)
training_time_min = (time.time() - start_train) / 60.0
print(f'Entrainement termine en {training_time_min:.2f} min')
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: ivannvasic05 (ivannvasic05-utbm) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260430_102053-dsh7chve</code>
# Syncing run <strong><a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/dsh7chve' target="_blank">Strategie2_Reweighting</a></strong> to <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity</a>
#  View run at <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/dsh7chve' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/dsh7chve</a>
# Modele initialise: ResNet
# Loss weights utilises: HF=2.0 | BF=0.7
# Ratio batch cible: HF=16/64 | BF=48/64
# Epoch 1: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 1/20 | Batch 1/117 | weighted_loss=2.4838 | 0.71 batch/s | ETA=2.7 min
# [CoTrain] Epoch 1/20 | Batch 10/117 | weighted_loss=2.4768 | 6.00 batch/s | ETA=0.3 min
# [CoTrain] Epoch 1/20 | Batch 20/117 | weighted_loss=2.2258 | 8.95 batch/s | ETA=0.2 min
# [CoTrain] Epoch 1/20 | Batch 30/117 | weighted_loss=2.2505 | 11.18 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 40/117 | weighted_loss=2.1053 | 13.10 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 50/117 | weighted_loss=1.9494 | 14.26 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 60/117 | weighted_loss=2.1815 | 15.15 batch/s | ETA=0.1 min
# [CoTrain] Epoch 1/20 | Batch 70/117 | weighted_loss=1.8138 | 16.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 80/117 | weighted_loss=2.1770 | 16.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 90/117 | weighted_loss=1.9510 | 16.85 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 100/117 | weighted_loss=2.0653 | 17.48 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 110/117 | weighted_loss=1.8561 | 17.70 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 | Batch 117/117 | weighted_loss=1.9695 | 17.95 batch/s | ETA=0.0 min
# [CoTrain] Epoch 1/20 en 0.12 min | weighted=2.1539 | hf_loss=2.1019 | bf_loss=2.1009 | val_loss=3.0117 | val_acc=19.11%
# Epoch 2: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 2/20 | Batch 1/117 | weighted_loss=2.1024 | 6.89 batch/s | ETA=0.3 min
# [CoTrain] Epoch 2/20 | Batch 10/117 | weighted_loss=1.7997 | 21.48 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 20/117 | weighted_loss=1.8783 | 19.95 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 30/117 | weighted_loss=1.8897 | 21.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 40/117 | weighted_loss=1.8080 | 22.50 batch/s | ETA=0.1 min
# [CoTrain] Epoch 2/20 | Batch 50/117 | weighted_loss=1.7204 | 23.17 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 60/117 | weighted_loss=1.6436 | 23.63 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 70/117 | weighted_loss=1.6882 | 22.91 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 80/117 | weighted_loss=1.7291 | 23.31 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 90/117 | weighted_loss=1.7394 | 23.67 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 100/117 | weighted_loss=1.8122 | 23.02 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 110/117 | weighted_loss=1.9807 | 23.29 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 | Batch 117/117 | weighted_loss=1.9786 | 23.59 batch/s | ETA=0.0 min
# [CoTrain] Epoch 2/20 en 0.09 min | weighted=1.8588 | hf_loss=1.7900 | bf_loss=1.8358 | val_loss=2.5121 | val_acc=29.51%
# Epoch 3: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 3/20 | Batch 1/117 | weighted_loss=1.5091 | 5.34 batch/s | ETA=0.4 min
# [CoTrain] Epoch 3/20 | Batch 10/117 | weighted_loss=1.6975 | 14.02 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 20/117 | weighted_loss=1.8291 | 16.80 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 30/117 | weighted_loss=1.5409 | 18.94 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 40/117 | weighted_loss=1.6719 | 20.38 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 50/117 | weighted_loss=1.8993 | 19.35 batch/s | ETA=0.1 min
# [CoTrain] Epoch 3/20 | Batch 60/117 | weighted_loss=1.6188 | 20.06 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 70/117 | weighted_loss=1.4371 | 20.56 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 80/117 | weighted_loss=1.9035 | 20.97 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 90/117 | weighted_loss=1.6782 | 21.48 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 100/117 | weighted_loss=1.3743 | 21.61 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 110/117 | weighted_loss=1.4905 | 22.03 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 | Batch 117/117 | weighted_loss=1.5144 | 21.00 batch/s | ETA=0.0 min
# [CoTrain] Epoch 3/20 en 0.10 min | weighted=1.6887 | hf_loss=1.6028 | bf_loss=1.6901 | val_loss=1.7906 | val_acc=38.85%
# Epoch 4: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 4/20 | Batch 1/117 | weighted_loss=1.6071 | 7.49 batch/s | ETA=0.3 min
# [CoTrain] Epoch 4/20 | Batch 10/117 | weighted_loss=1.7514 | 17.68 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 20/117 | weighted_loss=1.4496 | 17.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 30/117 | weighted_loss=1.5328 | 19.61 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 40/117 | weighted_loss=1.6954 | 20.14 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 50/117 | weighted_loss=1.2769 | 20.75 batch/s | ETA=0.1 min
# [CoTrain] Epoch 4/20 | Batch 60/117 | weighted_loss=1.6172 | 19.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 70/117 | weighted_loss=1.6444 | 19.25 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 80/117 | weighted_loss=1.6792 | 19.76 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 90/117 | weighted_loss=1.3889 | 20.16 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 100/117 | weighted_loss=1.5667 | 20.43 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 110/117 | weighted_loss=1.4836 | 20.12 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 | Batch 117/117 | weighted_loss=1.2881 | 20.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 4/20 en 0.10 min | weighted=1.5328 | hf_loss=1.4469 | bf_loss=1.5417 | val_loss=1.6803 | val_acc=45.01%
# Epoch 5: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 5/20 | Batch 1/117 | weighted_loss=1.4694 | 6.96 batch/s | ETA=0.3 min
# [CoTrain] Epoch 5/20 | Batch 10/117 | weighted_loss=1.2734 | 21.18 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 20/117 | weighted_loss=1.2154 | 20.82 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 30/117 | weighted_loss=1.3912 | 21.53 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 40/117 | weighted_loss=1.3807 | 22.53 batch/s | ETA=0.1 min
# [CoTrain] Epoch 5/20 | Batch 50/117 | weighted_loss=1.5665 | 22.54 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 60/117 | weighted_loss=1.5217 | 23.14 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 70/117 | weighted_loss=1.3508 | 23.55 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 80/117 | weighted_loss=1.7149 | 22.91 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 90/117 | weighted_loss=1.0963 | 23.18 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 100/117 | weighted_loss=1.5313 | 22.78 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 110/117 | weighted_loss=1.7551 | 22.72 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 | Batch 117/117 | weighted_loss=1.3313 | 23.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 5/20 en 0.09 min | weighted=1.3774 | hf_loss=1.2747 | bf_loss=1.4097 | val_loss=1.3652 | val_acc=53.29%
# Epoch 6: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 6/20 | Batch 1/117 | weighted_loss=1.2415 | 6.95 batch/s | ETA=0.3 min
# [CoTrain] Epoch 6/20 | Batch 10/117 | weighted_loss=1.2405 | 18.72 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 20/117 | weighted_loss=1.2615 | 17.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 30/117 | weighted_loss=1.1964 | 19.47 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 40/117 | weighted_loss=1.3205 | 20.19 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 50/117 | weighted_loss=1.3393 | 21.07 batch/s | ETA=0.1 min
# [CoTrain] Epoch 6/20 | Batch 60/117 | weighted_loss=1.5100 | 21.17 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 70/117 | weighted_loss=1.0639 | 21.71 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 80/117 | weighted_loss=0.9424 | 22.25 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 90/117 | weighted_loss=1.2112 | 22.21 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 100/117 | weighted_loss=1.2691 | 22.03 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 110/117 | weighted_loss=1.3065 | 22.37 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 | Batch 117/117 | weighted_loss=1.1106 | 22.71 batch/s | ETA=0.0 min
# [CoTrain] Epoch 6/20 en 0.09 min | weighted=1.3039 | hf_loss=1.1750 | bf_loss=1.3646 | val_loss=1.4303 | val_acc=51.59%
# Epoch 7: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 7/20 | Batch 1/117 | weighted_loss=1.1881 | 6.97 batch/s | ETA=0.3 min
# [CoTrain] Epoch 7/20 | Batch 10/117 | weighted_loss=0.9609 | 13.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 20/117 | weighted_loss=1.1753 | 17.98 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 30/117 | weighted_loss=1.1502 | 20.12 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 40/117 | weighted_loss=1.4718 | 19.47 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 50/117 | weighted_loss=1.1365 | 20.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 7/20 | Batch 60/117 | weighted_loss=1.0605 | 21.31 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 70/117 | weighted_loss=1.2543 | 21.98 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 80/117 | weighted_loss=0.9240 | 21.63 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 90/117 | weighted_loss=1.1684 | 22.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 100/117 | weighted_loss=1.0835 | 21.46 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 110/117 | weighted_loss=1.0069 | 21.60 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 | Batch 117/117 | weighted_loss=1.1657 | 21.26 batch/s | ETA=0.0 min
# [CoTrain] Epoch 7/20 en 0.10 min | weighted=1.1898 | hf_loss=1.0412 | bf_loss=1.2747 | val_loss=1.4846 | val_acc=47.56%
# Epoch 8: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 8/20 | Batch 1/117 | weighted_loss=1.4356 | 6.93 batch/s | ETA=0.3 min
# [CoTrain] Epoch 8/20 | Batch 10/117 | weighted_loss=1.0001 | 21.70 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 20/117 | weighted_loss=1.2636 | 21.85 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 30/117 | weighted_loss=1.1777 | 19.39 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 40/117 | weighted_loss=0.9469 | 20.67 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 50/117 | weighted_loss=1.2319 | 19.79 batch/s | ETA=0.1 min
# [CoTrain] Epoch 8/20 | Batch 60/117 | weighted_loss=1.0992 | 19.84 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 70/117 | weighted_loss=0.9795 | 20.50 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 80/117 | weighted_loss=1.2352 | 21.06 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 90/117 | weighted_loss=1.4526 | 19.81 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 100/117 | weighted_loss=1.3219 | 20.09 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 110/117 | weighted_loss=1.3608 | 19.86 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 | Batch 117/117 | weighted_loss=1.4361 | 20.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 8/20 en 0.10 min | weighted=1.1329 | hf_loss=0.9644 | bf_loss=1.2394 | val_loss=1.4737 | val_acc=51.80%
# Epoch 9: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 9/20 | Batch 1/117 | weighted_loss=0.8895 | 6.83 batch/s | ETA=0.3 min
# [CoTrain] Epoch 9/20 | Batch 10/117 | weighted_loss=1.0581 | 19.98 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 20/117 | weighted_loss=0.8075 | 21.57 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 30/117 | weighted_loss=0.9305 | 18.71 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 40/117 | weighted_loss=0.8678 | 18.51 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 50/117 | weighted_loss=1.0369 | 18.56 batch/s | ETA=0.1 min
# [CoTrain] Epoch 9/20 | Batch 60/117 | weighted_loss=0.9954 | 19.19 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 70/117 | weighted_loss=1.1336 | 19.94 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 80/117 | weighted_loss=1.0154 | 20.58 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 90/117 | weighted_loss=1.1532 | 20.07 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 100/117 | weighted_loss=0.9274 | 20.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 110/117 | weighted_loss=1.2470 | 20.34 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 | Batch 117/117 | weighted_loss=1.3812 | 20.52 batch/s | ETA=0.0 min
# [CoTrain] Epoch 9/20 en 0.10 min | weighted=1.0254 | hf_loss=0.8445 | bf_loss=1.1489 | val_loss=1.2654 | val_acc=57.96%
# Epoch 10: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 10/20 | Batch 1/117 | weighted_loss=1.0038 | 7.50 batch/s | ETA=0.3 min
# [CoTrain] Epoch 10/20 | Batch 10/117 | weighted_loss=1.0877 | 17.36 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 20/117 | weighted_loss=0.8047 | 20.08 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 30/117 | weighted_loss=0.8043 | 21.81 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 40/117 | weighted_loss=1.0138 | 21.29 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 50/117 | weighted_loss=0.8244 | 22.09 batch/s | ETA=0.1 min
# [CoTrain] Epoch 10/20 | Batch 60/117 | weighted_loss=0.8857 | 22.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 70/117 | weighted_loss=0.9125 | 22.72 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 80/117 | weighted_loss=1.3855 | 23.08 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 90/117 | weighted_loss=0.8784 | 23.44 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 100/117 | weighted_loss=1.1000 | 23.26 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 110/117 | weighted_loss=0.9119 | 22.18 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 | Batch 117/117 | weighted_loss=1.3847 | 22.08 batch/s | ETA=0.0 min
# [CoTrain] Epoch 10/20 en 0.10 min | weighted=0.9511 | hf_loss=0.7136 | bf_loss=1.1320 | val_loss=1.2111 | val_acc=57.96%
# Epoch 11: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 11/20 | Batch 1/117 | weighted_loss=0.8931 | 7.47 batch/s | ETA=0.3 min
# [CoTrain] Epoch 11/20 | Batch 10/117 | weighted_loss=0.9873 | 18.13 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 20/117 | weighted_loss=0.8634 | 21.22 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 30/117 | weighted_loss=1.0501 | 22.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 40/117 | weighted_loss=0.8121 | 22.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 11/20 | Batch 50/117 | weighted_loss=0.8777 | 23.39 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 60/117 | weighted_loss=1.0752 | 22.32 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 70/117 | weighted_loss=0.7082 | 22.83 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 80/117 | weighted_loss=1.1032 | 23.25 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 90/117 | weighted_loss=0.7550 | 23.59 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 100/117 | weighted_loss=0.9422 | 23.31 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 110/117 | weighted_loss=1.0087 | 23.65 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 | Batch 117/117 | weighted_loss=0.8710 | 23.90 batch/s | ETA=0.0 min
# [CoTrain] Epoch 11/20 en 0.09 min | weighted=0.8626 | hf_loss=0.5869 | bf_loss=1.0840 | val_loss=1.5244 | val_acc=53.29%
# Epoch 12: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 12/20 | Batch 1/117 | weighted_loss=0.9039 | 6.95 batch/s | ETA=0.3 min
# [CoTrain] Epoch 12/20 | Batch 10/117 | weighted_loss=0.9816 | 19.02 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 20/117 | weighted_loss=0.8189 | 22.10 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 30/117 | weighted_loss=0.9399 | 20.93 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 40/117 | weighted_loss=0.7104 | 21.99 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 50/117 | weighted_loss=0.7118 | 21.44 batch/s | ETA=0.1 min
# [CoTrain] Epoch 12/20 | Batch 60/117 | weighted_loss=0.7784 | 22.18 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 70/117 | weighted_loss=0.7183 | 21.79 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 80/117 | weighted_loss=1.0466 | 22.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 90/117 | weighted_loss=0.6633 | 22.27 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 100/117 | weighted_loss=0.8502 | 22.17 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 110/117 | weighted_loss=0.6732 | 22.52 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 | Batch 117/117 | weighted_loss=0.9105 | 22.86 batch/s | ETA=0.0 min
# [CoTrain] Epoch 12/20 en 0.09 min | weighted=0.7721 | hf_loss=0.4901 | bf_loss=1.0039 | val_loss=1.3290 | val_acc=58.17%
# Epoch 13: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 13/20 | Batch 1/117 | weighted_loss=0.9103 | 7.08 batch/s | ETA=0.3 min
# [CoTrain] Epoch 13/20 | Batch 10/117 | weighted_loss=0.6402 | 17.89 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 20/117 | weighted_loss=0.3968 | 18.36 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 30/117 | weighted_loss=0.6929 | 20.03 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 40/117 | weighted_loss=0.7295 | 21.14 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 50/117 | weighted_loss=0.6931 | 22.04 batch/s | ETA=0.1 min
# [CoTrain] Epoch 13/20 | Batch 60/117 | weighted_loss=0.6659 | 20.85 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 70/117 | weighted_loss=0.4927 | 20.08 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 80/117 | weighted_loss=0.5990 | 20.63 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 90/117 | weighted_loss=0.9851 | 20.77 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 100/117 | weighted_loss=0.8019 | 21.17 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 110/117 | weighted_loss=0.7071 | 21.59 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 | Batch 117/117 | weighted_loss=0.8364 | 21.70 batch/s | ETA=0.0 min
# [CoTrain] Epoch 13/20 en 0.10 min | weighted=0.6986 | hf_loss=0.3966 | bf_loss=0.9529 | val_loss=1.3822 | val_acc=58.81%
# Epoch 14: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 14/20 | Batch 1/117 | weighted_loss=0.6404 | 6.99 batch/s | ETA=0.3 min
# [CoTrain] Epoch 14/20 | Batch 10/117 | weighted_loss=0.8550 | 17.66 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 20/117 | weighted_loss=0.6590 | 19.99 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 30/117 | weighted_loss=0.4952 | 20.41 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 40/117 | weighted_loss=0.4837 | 21.72 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 50/117 | weighted_loss=0.7248 | 21.24 batch/s | ETA=0.1 min
# [CoTrain] Epoch 14/20 | Batch 60/117 | weighted_loss=0.5321 | 20.76 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 70/117 | weighted_loss=0.6087 | 21.48 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 80/117 | weighted_loss=0.5834 | 21.61 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 90/117 | weighted_loss=0.6493 | 22.06 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 100/117 | weighted_loss=0.4926 | 22.43 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 110/117 | weighted_loss=0.6935 | 22.76 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 | Batch 117/117 | weighted_loss=0.6311 | 22.88 batch/s | ETA=0.0 min
# [CoTrain] Epoch 14/20 en 0.09 min | weighted=0.6543 | hf_loss=0.3090 | bf_loss=0.9519 | val_loss=1.2942 | val_acc=60.30%
# Epoch 15: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 15/20 | Batch 1/117 | weighted_loss=0.4944 | 7.62 batch/s | ETA=0.3 min
# [CoTrain] Epoch 15/20 | Batch 10/117 | weighted_loss=0.4981 | 17.76 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 20/117 | weighted_loss=0.5479 | 20.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 30/117 | weighted_loss=0.4562 | 22.23 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 40/117 | weighted_loss=0.6313 | 22.16 batch/s | ETA=0.1 min
# [CoTrain] Epoch 15/20 | Batch 50/117 | weighted_loss=0.5498 | 22.80 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 60/117 | weighted_loss=0.6656 | 22.53 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 70/117 | weighted_loss=0.5790 | 22.46 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 80/117 | weighted_loss=0.6440 | 22.87 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 90/117 | weighted_loss=0.5547 | 23.15 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 100/117 | weighted_loss=0.5215 | 23.18 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 110/117 | weighted_loss=0.4921 | 23.10 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 | Batch 117/117 | weighted_loss=0.7480 | 23.10 batch/s | ETA=0.0 min
# [CoTrain] Epoch 15/20 en 0.09 min | weighted=0.5615 | hf_loss=0.2165 | bf_loss=0.8632 | val_loss=1.4575 | val_acc=59.66%
# Epoch 16: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 16/20 | Batch 1/117 | weighted_loss=0.6705 | 7.14 batch/s | ETA=0.3 min
# [CoTrain] Epoch 16/20 | Batch 10/117 | weighted_loss=0.5201 | 20.47 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 20/117 | weighted_loss=0.5962 | 21.90 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 30/117 | weighted_loss=0.3828 | 20.92 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 40/117 | weighted_loss=0.6072 | 20.91 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 50/117 | weighted_loss=0.4978 | 21.15 batch/s | ETA=0.1 min
# [CoTrain] Epoch 16/20 | Batch 60/117 | weighted_loss=0.5798 | 20.89 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 70/117 | weighted_loss=0.5363 | 21.60 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 80/117 | weighted_loss=0.7389 | 21.40 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 90/117 | weighted_loss=0.5428 | 21.95 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 100/117 | weighted_loss=0.5769 | 22.36 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 110/117 | weighted_loss=0.4382 | 22.73 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 | Batch 117/117 | weighted_loss=0.5339 | 22.93 batch/s | ETA=0.0 min
# [CoTrain] Epoch 16/20 en 0.09 min | weighted=0.5251 | hf_loss=0.1735 | bf_loss=0.8349 | val_loss=1.3211 | val_acc=60.30%
# Epoch 17: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 17/20 | Batch 1/117 | weighted_loss=0.3925 | 6.83 batch/s | ETA=0.3 min
# [CoTrain] Epoch 17/20 | Batch 10/117 | weighted_loss=0.3255 | 21.63 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 20/117 | weighted_loss=0.5226 | 21.55 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 30/117 | weighted_loss=0.3977 | 21.69 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 40/117 | weighted_loss=0.4852 | 22.70 batch/s | ETA=0.1 min
# [CoTrain] Epoch 17/20 | Batch 50/117 | weighted_loss=0.3803 | 23.38 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 60/117 | weighted_loss=0.3988 | 23.19 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 70/117 | weighted_loss=0.4121 | 23.23 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 80/117 | weighted_loss=0.8065 | 22.73 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 90/117 | weighted_loss=0.3779 | 23.11 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 100/117 | weighted_loss=0.5962 | 23.32 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 110/117 | weighted_loss=0.4694 | 22.53 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 | Batch 117/117 | weighted_loss=0.5206 | 22.84 batch/s | ETA=0.0 min
# [CoTrain] Epoch 17/20 en 0.09 min | weighted=0.4867 | hf_loss=0.1517 | bf_loss=0.7826 | val_loss=1.3067 | val_acc=62.85%
# Epoch 18: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 18/20 | Batch 1/117 | weighted_loss=0.4927 | 7.32 batch/s | ETA=0.3 min
# [CoTrain] Epoch 18/20 | Batch 10/117 | weighted_loss=0.5324 | 17.80 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 20/117 | weighted_loss=0.4771 | 21.23 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 30/117 | weighted_loss=0.3866 | 19.45 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 40/117 | weighted_loss=0.4961 | 20.79 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 50/117 | weighted_loss=0.3590 | 20.65 batch/s | ETA=0.1 min
# [CoTrain] Epoch 18/20 | Batch 60/117 | weighted_loss=0.5340 | 21.19 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 70/117 | weighted_loss=0.5797 | 20.47 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 80/117 | weighted_loss=0.4802 | 21.04 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 90/117 | weighted_loss=0.3417 | 21.51 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 100/117 | weighted_loss=0.4825 | 21.22 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 110/117 | weighted_loss=0.5169 | 20.77 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 | Batch 117/117 | weighted_loss=0.4235 | 20.89 batch/s | ETA=0.0 min
# [CoTrain] Epoch 18/20 en 0.10 min | weighted=0.4351 | hf_loss=0.1116 | bf_loss=0.7224 | val_loss=1.3785 | val_acc=63.06%
# Epoch 19: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 19/20 | Batch 1/117 | weighted_loss=0.3840 | 7.05 batch/s | ETA=0.3 min
# [CoTrain] Epoch 19/20 | Batch 10/117 | weighted_loss=0.3787 | 19.62 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 20/117 | weighted_loss=0.3754 | 22.58 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 30/117 | weighted_loss=0.3561 | 23.61 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 40/117 | weighted_loss=0.4944 | 23.00 batch/s | ETA=0.1 min
# [CoTrain] Epoch 19/20 | Batch 50/117 | weighted_loss=0.2674 | 23.41 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 60/117 | weighted_loss=0.4039 | 22.81 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 70/117 | weighted_loss=0.4954 | 23.16 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 80/117 | weighted_loss=0.3778 | 22.71 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 90/117 | weighted_loss=0.3415 | 22.51 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 100/117 | weighted_loss=0.5032 | 22.79 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 110/117 | weighted_loss=0.3937 | 21.96 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 | Batch 117/117 | weighted_loss=0.3123 | 22.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 19/20 en 0.10 min | weighted=0.4063 | hf_loss=0.0915 | bf_loss=0.6867 | val_loss=1.3247 | val_acc=64.97%
# Epoch 20: composition premier batch HF=16, BF=48
# [CoTrain] Epoch 20/20 | Batch 1/117 | weighted_loss=0.3655 | 7.07 batch/s | ETA=0.3 min
# [CoTrain] Epoch 20/20 | Batch 10/117 | weighted_loss=0.3318 | 20.27 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 20/117 | weighted_loss=0.3372 | 20.05 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 30/117 | weighted_loss=0.4670 | 19.19 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 40/117 | weighted_loss=0.3435 | 20.52 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 50/117 | weighted_loss=0.4628 | 21.38 batch/s | ETA=0.1 min
# [CoTrain] Epoch 20/20 | Batch 60/117 | weighted_loss=0.3070 | 21.75 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 70/117 | weighted_loss=0.4404 | 22.37 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 80/117 | weighted_loss=0.3698 | 22.05 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 90/117 | weighted_loss=0.4340 | 22.42 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 100/117 | weighted_loss=0.4106 | 22.44 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 110/117 | weighted_loss=0.6815 | 22.70 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 | Batch 117/117 | weighted_loss=0.4302 | 22.64 batch/s | ETA=0.0 min
# [CoTrain] Epoch 20/20 en 0.09 min | weighted=0.3993 | hf_loss=0.0877 | bf_loss=0.6770 | val_loss=1.6011 | val_acc=59.02%
# Entrainement termine en 1.95 min

# %% [markdown]
# ## 6) Evaluation finale, cout, sauvegarde et visualisation

# %%
criterion = nn.CrossEntropyLoss()
test_hf_loss, test_hf_acc = evaluate(model, loader_test_hf, criterion)
test_bf_loss, test_bf_acc = evaluate(model, loader_test_bf, criterion)
test_mix_acc = (test_hf_acc + test_bf_acc) / 2.0

hf_seen_per_epoch = mixed_batch_sampler.hf_per_batch * len(loader_mixed_train)
bf_seen_per_epoch = mixed_batch_sampler.bf_per_batch * len(loader_mixed_train)
hf_seen_total = hf_seen_per_epoch * EPOCHS
bf_seen_total = bf_seen_per_epoch * EPOCHS
total_cost = hf_seen_total * COST_HF + bf_seen_total * COST_BF

results = {
    'strategy': 'cotraining_batch_reweighting',
    'dataset': 'Animals-10',
    'pipeline': 'mixed_batches_with_domain_weighted_loss',
    'epochs': EPOCHS,
    'lr': LR,
    'batch_size': BATCH_SIZE,
    'hf_batch_ratio': HF_BATCH_RATIO,
    'hf_per_batch': mixed_batch_sampler.hf_per_batch,
    'bf_per_batch': mixed_batch_sampler.bf_per_batch,
    'hf_loss_weight': HF_LOSS_WEIGHT,
    'bf_loss_weight': BF_LOSS_WEIGHT,
    'hf_seen_total_samples': int(hf_seen_total),
    'bf_seen_total_samples': int(bf_seen_total),
    'total_cost_CA': int(total_cost),
    'training_time_min': float(training_time_min),
    'test_hf_loss': float(test_hf_loss),
    'test_bf_loss': float(test_bf_loss),
    'accuracy_HF': float(test_hf_acc),
    'accuracy_BF': float(test_bf_acc),
    'accuracy_Mixte': float(test_mix_acc),
    'history': history
}

json_path = os.path.join(RESULTS_DIR, 'results_strategy2_cotraining_reweighting.json')
pth_path = os.path.join(RESULTS_DIR, 'model_strategy2_cotraining_reweighting.pth')
png_path = os.path.join(RESULTS_DIR, 'strategy2_cotraining_reweighting_curves.png')

with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

torch.save(model.state_dict(), pth_path)

print('--- RESULTATS FINAUX (Animals-10 - Strategie 2) ---')
print(f"Test HF    : {test_hf_acc:.2f}%")
print(f"Test BF    : {test_bf_acc:.2f}%")
print(f"Test Mixte : {test_mix_acc:.2f}%")
print(f"Cout total : {total_cost} CA")
print(f"Temps total: {training_time_min:.2f} min")
print('JSON sauve :', json_path)
print('Model sauve:', pth_path)

x = np.arange(1, EPOCHS + 1)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(x, history['train_weighted_loss'], marker='o', label='Train loss ponderee (HF/BF)')
axes[0].plot(x, history['val_loss'], marker='o', linestyle='--', label='Val loss HF')
axes[0].plot(x, history['train_hf_loss'], marker='o', alpha=0.7, label='Train HF loss (non ponderee)')
axes[0].plot(x, history['train_bf_loss'], marker='o', alpha=0.7, label='Train BF loss (non ponderee)')
axes[0].set_title('Evolution des losses - Strategie 2')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)
axes[0].legend(fontsize=8)

axes[1].plot(x, history['val_acc'], marker='o', color='tab:green', label='Val accuracy HF')
axes[1].set_title('Precision validation HF')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')
axes[1].grid(alpha=0.3)
axes[1].legend(fontsize=9)

plt.tight_layout()
plt.savefig(png_path, dpi=180, bbox_inches='tight')
plt.show()
print('Figure sauvee:', png_path)

# --- W&B : log final + upload artefacts + finish ---
if USE_WANDB and _WANDB_AVAILABLE and wandb.run is not None:
    wandb.log({
        "test/accuracy_HF": test_hf_acc,
        "test/accuracy_BF": test_bf_acc,
        "test/accuracy_Mixte": test_mix_acc,
        "test/loss_HF": test_hf_loss,
        "test/loss_BF": test_bf_loss,
        "total_cost_CA": int(total_cost),
        "total_time_min": training_time_min,
        "hf_seen_total_samples": int(hf_seen_total),
        "bf_seen_total_samples": int(bf_seen_total),
    })
    wandb.summary["final/accuracy_HF"] = test_hf_acc
    wandb.summary["final/accuracy_BF"] = test_bf_acc
    wandb.summary["final/accuracy_Mixte"] = test_mix_acc
    wandb.summary["final/total_cost_CA"] = int(total_cost)
    wandb.summary["final/total_time_min"] = training_time_min

    try:
        wandb.save(pth_path)
        wandb.save(json_path)
        wandb.save(png_path)
    except Exception as e:
        print(f"⚠️ wandb.save a échoué : {e}")

    wandb.finish()
    print("📡 Run W&B clôturé proprement.")
# Out:
# --- RESULTATS FINAUX (Animals-10 - Strategie 2) ---
# Test HF    : 62.47%
# Test BF    : 58.95%
# Test Mixte : 60.71%
# Cout total : 486720 CA
# Temps total: 1.95 min
# JSON sauve : /content/drive/MyDrive/UTBM_PF22/results/results_strategy2_cotraining_reweighting.json
# Model sauve: /content/drive/MyDrive/UTBM_PF22/results/model_strategy2_cotraining_reweighting.pth
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Figure sauvee: /content/drive/MyDrive/UTBM_PF22/results/strategy2_cotraining_reweighting_curves.png
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>bf_seen_total_samples</td><td>▁</td></tr><tr><td>cumulative_cost_CA</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>epoch_time_min</td><td>█▁▄▅▂▂▄▅▅▃▁▂▃▂▂▂▂▄▃▂</td></tr><tr><td>hf_seen_total_samples</td><td>▁</td></tr><tr><td>test/accuracy_BF</td><td>▁</td></tr><tr><td>test/accuracy_HF</td><td>▁</td></tr><tr><td>test/accuracy_Mixte</td><td>▁</td></tr><tr><td>test/loss_BF</td><td>▁</td></tr><tr><td>test/loss_HF</td><td>▁</td></tr><tr><td>+7</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>bf_seen_total_samples</td><td>112320</td></tr><tr><td>cumulative_cost_CA</td><td>486720</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>epoch_time_min</td><td>0.09416</td></tr><tr><td>final/accuracy_BF</td><td>58.9518</td></tr><tr><td>final/accuracy_HF</td><td>62.47131</td></tr><tr><td>final/accuracy_Mixte</td><td>60.71155</td></tr><tr><td>final/total_cost_CA</td><td>486720</td></tr><tr><td>final/total_time_min</td><td>1.94885</td></tr><tr><td>hf_seen_total_samples</td><td>37440</td></tr><tr><td>+12</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Strategie2_Reweighting</strong> at: <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/dsh7chve' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/dsh7chve</a><br> View project at: <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20260430_102053-dsh7chve/logs</code>
# 📡 Run W&B clôturé proprement.

# %% [markdown]
# ## 7) Comparaison optionnelle avec baselines et strategie 1

# %%
comparison_files = {
    'BL 1(HF)': 'results_baseline_HF.json',
    'BL 2(BF)': 'results_baseline_BF.json',
    'BL 3(MIXTE)': 'results_baseline_MIXTE.json',
    'Strategie 1(BF->HF)': 'results_strategy1_transfer_learning.json',
    'Strategie 2(CoTrain)': 'results_strategy2_cotraining_reweighting.json'
}

rows = []
for name, fn in comparison_files.items():
    p = os.path.join(RESULTS_DIR, fn)
    if os.path.exists(p):
        with open(p, 'r', encoding='utf-8') as f:
            d = json.load(f)
        rows.append((
            name,
            d.get('accuracy_HF', np.nan),
            d.get('accuracy_BF', np.nan),
            d.get('accuracy_Mixte', np.nan),
            d.get('total_cost_CA', np.nan),
            d.get('training_time_min', d.get('total_time_min', np.nan))
        ))

if not rows:
    print('Aucun fichier JSON trouve pour la comparaison.')
else:
    header = f"{'Modele':<25} {'HF%':>8} {'BF%':>8} {'Mixte%':>10} {'Cout(CA)':>12} {'Temps(min)':>12}"
    print(header)
    print('-' * len(header))
    for r in rows:
        print(f"{r[0]:<25} {r[1]:>8.2f} {r[2]:>8.2f} {r[3]:>10.2f} {r[4]:>12.0f} {r[5]:>12.2f}")
# Out:
# Modele                         HF%      BF%     Mixte%     Cout(CA)   Temps(min)
# --------------------------------------------------------------------------------
# BL 1(HF)                     55.28    31.79      43.53       470400          nan
# BL 2(BF)                     34.05    32.75      33.40        21213          nan
# BL 3(MIXTE)                  75.02    63.70      69.36       894660          nan
# Strategie 1(BF->HF)          78.16    58.07      68.11       400230         2.96
# Strategie 2(CoTrain)         62.47    58.95      60.71       486720         1.95
