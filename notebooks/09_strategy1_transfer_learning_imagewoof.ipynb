# %% [markdown]
# # Partie 4 - Etape 1 (Imagewoof) : Transfer Learning Sequentiel
#
# Reprise stricte du protocole du notebook `04_strategy1_transfer_learning.ipynb` mais sur le **dataset Imagewoof** preparé par `07_Prepare_New_Dataset.ipynb`.
#
# ## Objectif
# - Phase A: pre-entrainer un ResNet-18 sur le domaine BF (images degradees).
# - Phase B: faire un fine-tuning sur le domaine HF (images propres).
# - Evaluer ensuite sur test HF, test BF et precision mixte.
#
# ## Sorties attendues
# - Metriques finales (HF, BF, Mixte, temps, cout) pour Imagewoof.
# - Courbes de loss/accuracy par phase.
# - Sauvegarde JSON + poids du modele final dans `results/Imagewoof/`.

# %%
import os
import json
import time
import random
import shutil
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.benchmark = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Appareil: {device}')
# Out:
# Appareil: cuda

# %% [markdown]
# ## 1) Montage Drive et chemins de travail (Imagewoof)
# Ce bloc supporte a la fois Colab et un execution locale. Differences avec `04` :
# - `zip_source` pointe vers le ZIP Imagewoof,
# - les fallbacks Drive cherchent dans le dossier Imagewoof,
# - `RESULTS_DIR` ecrit dans le sous-dossier `results/Imagewoof/` pour ne pas ecraser les resultats Animals-10.

# %%
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive', force_remount=True)

    local_base = '/content/processed_multifidelity'
    zip_source = '/content/drive/MyDrive/UTBM_PF22/datasets/Imagewoof/dataset_multifidelity.zip'
    drive_base_candidates = [
        '/content/drive/MyDrive/UTBM_PF22/datasets/Imagewoof/processed_multifidelity',
        '/content/drive/MyDrive/UTBM_PF22/results/datasets/Imagewoof/processed_multifidelity',
    ]

    if os.path.exists(local_base):
        print('Dataset deja present sur SSD local, reutilisation.')
        BASE_DIR = local_base
    else:
        if os.path.exists(zip_source):
            print('Extraction du zip dataset Imagewoof vers SSD local...')
            start = time.time()
            shutil.copy2(zip_source, '/content/dataset_multifidelity.zip')
            import zipfile
            with zipfile.ZipFile('/content/dataset_multifidelity.zip', 'r') as zip_ref:
                zip_ref.extractall('/content/')
            os.remove('/content/dataset_multifidelity.zip')
            print(f'Dataset extrait sur SSD en {time.time()-start:.2f}s')
            BASE_DIR = local_base if os.path.exists(local_base) else None
        else:
            BASE_DIR = None

        if BASE_DIR is None:
            drive_base = next((p for p in drive_base_candidates if os.path.exists(p)), None)
            if drive_base is None:
                raise FileNotFoundError(
                    'Aucun dataset Imagewoof trouve. Chemins testes: '
                    + ' | '.join([zip_source] + drive_base_candidates)
                )
            print('SSD indisponible, fallback vers le dossier Drive deja prepare.')
            BASE_DIR = drive_base

    RESULTS_DIR = '/content/drive/MyDrive/UTBM_PF22/results/Imagewoof'
else:
    candidate_base_dirs = [
        '../data/processed_multifidelity',
        './data/processed_multifidelity',
        'data/processed_multifidelity',
    ]
    BASE_DIR = next((p for p in candidate_base_dirs if os.path.exists(p)), None)
    if BASE_DIR is None:
        raise FileNotFoundError(
            'Aucun dossier processed_multifidelity trouve. Chemins testes: '
            + ' | '.join(candidate_base_dirs)
        )
    RESULTS_DIR = '../results/Imagewoof'

os.makedirs(RESULTS_DIR, exist_ok=True)
print('BASE_DIR selectionne =', BASE_DIR)
print('RESULTS_DIR         =', RESULTS_DIR)
# Out:
# Mounted at /content/drive
# Extraction du zip dataset Imagewoof vers SSD local...
# Dataset extrait sur SSD en 18.35s
# BASE_DIR selectionne = /content/processed_multifidelity
# RESULTS_DIR         = /content/drive/MyDrive/UTBM_PF22/results/Imagewoof

# %% [markdown]
# ## 2) Datasets et transforms
# On reprend le meme protocole de degradation que les baselines pour le test BF.
#
# Imagewoof a 10 classes (`num_classes=10`), comme Animals-10, donc l'architecture du modele est inchangee.

# %%
COST_HF = 10
COST_BF = 1
BATCH_SIZE = 64
NUM_WORKERS = 2 if '/content/processed_multifidelity' in str(BASE_DIR) else 0
PRETRAIN_EPOCHS = 10
FINETUNE_EPOCHS = 10
LR_PRETRAIN = 1e-3
LR_FINETUNE = 3e-4
HF_TRAIN_RATIO = 0.8

class AddDegradationTransform:
    """Degrade un tenseur image pour simuler le domaine BF."""
    def __call__(self, img_tensor):
        h, w = img_tensor.shape[1], img_tensor.shape[2]
        img_degraded = transforms.functional.resize(img_tensor, (64, 64), antialias=True)
        img_degraded = transforms.functional.resize(img_degraded, (h, w), antialias=True)
        noise = torch.randn_like(img_degraded) * 0.15
        img_noisy = img_degraded + noise
        return torch.clamp(img_noisy, 0, 1)

transform_standard = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_bf_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    AddDegradationTransform(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

required_dirs = [
    os.path.join(BASE_DIR, 'train', 'BF'),
    os.path.join(BASE_DIR, 'train', 'HF'),
    os.path.join(BASE_DIR, 'test'),
]
missing = [p for p in required_dirs if not os.path.isdir(p)]
if missing:
    raise FileNotFoundError(
        'Structure dataset invalide. Dossiers manquants: ' + ' | '.join(missing)
    )

dataset_bf_train = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/BF'), transform=transform_standard)
dataset_hf_full = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/HF'), transform=transform_standard)
dataset_test_hf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_standard)
dataset_test_bf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_bf_test)

hf_train_size = int(HF_TRAIN_RATIO * len(dataset_hf_full))
hf_val_size = len(dataset_hf_full) - hf_train_size
dataset_hf_train, dataset_hf_val = random_split(
    dataset_hf_full,
    [hf_train_size, hf_val_size],
    generator=torch.Generator().manual_seed(SEED)
)

loader_bf_train = DataLoader(dataset_bf_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
loader_hf_train = DataLoader(dataset_hf_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
loader_hf_val = DataLoader(dataset_hf_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_hf = DataLoader(dataset_test_hf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_bf = DataLoader(dataset_test_bf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f'Train BF: {len(dataset_bf_train)} images')
print(f'Train HF (fine-tune): {len(dataset_hf_train)} images')
print(f'Val HF: {len(dataset_hf_val)} images')
print(f'Test HF/BF: {len(dataset_test_hf)} images')
print(f'NUM_WORKERS utilise: {NUM_WORKERS}')
print(f'Nb batches BF: {len(loader_bf_train)} | Nb batches HF: {len(loader_hf_train)}')
print(f'Classes: {dataset_hf_full.classes}')
# Out:
# Train BF: 8126 images
# Train HF (fine-tune): 719 images
# Val HF: 180 images
# Test HF/BF: 3929 images
# NUM_WORKERS utilise: 2
# Nb batches BF: 127 | Nb batches HF: 12
# Classes: ['n02086240', 'n02087394', 'n02088364', 'n02089973', 'n02093754', 'n02096294', 'n02099601', 'n02105641', 'n02111889', 'n02115641']

# %% [markdown]
# ## 3) Utilitaires de modelisation
# - Initialisation ResNet-18 from scratch
# - Boucle d'entrainement AMP
# - Evaluation par domaine

# %%
def create_model(num_classes=10):
    model = models.resnet18(weights=None)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)
            total_loss += loss.item() * x.size(0)
            total_correct += (logits.argmax(dim=1) == y).sum().item()
            total_samples += x.size(0)
    return total_loss / total_samples, 100.0 * total_correct / total_samples

def make_grad_scaler():
    try:
        return GradScaler('cuda', enabled=(device.type == 'cuda'))
    except TypeError:
        return GradScaler(enabled=(device.type == 'cuda'))

def train_phase(model, train_loader, val_loader, epochs, lr, phase_name):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = make_grad_scaler()

    hist = {'train_loss': [], 'val_loss': [], 'val_acc': []}
    phase_start = time.time()
    log_every = 10

    for epoch in range(1, epochs + 1):
        model.train()
        running_loss = 0.0
        total = 0
        epoch_start = time.time()

        for batch_idx, (x, y) in enumerate(train_loader, start=1):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad(set_to_none=True)

            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item() * x.size(0)
            total += x.size(0)

            if batch_idx % log_every == 0 or batch_idx == 1 or batch_idx == len(train_loader):
                elapsed = time.time() - epoch_start
                bps = batch_idx / elapsed if elapsed > 0 else 0.0
                eta_sec = (len(train_loader) - batch_idx) / bps if bps > 0 else 0.0
                print(
                    f'[{phase_name}] Epoch {epoch}/{epochs} | Batch {batch_idx}/{len(train_loader)} | '
                    f'loss_batch={loss.item():.4f} | {bps:.2f} batch/s | ETA epoch={eta_sec/60:.1f} min'
                )

        train_loss = running_loss / total
        val_loss, val_acc = evaluate(model, val_loader, criterion)
        epoch_min = (time.time() - epoch_start) / 60.0

        hist['train_loss'].append(train_loss)
        hist['val_loss'].append(val_loss)
        hist['val_acc'].append(val_acc)

        print(
            f'[{phase_name}] Epoch {epoch}/{epochs} terminee en {epoch_min:.2f} min | '
            f'train_loss={train_loss:.4f} | val_loss={val_loss:.4f} | val_acc={val_acc:.2f}%'
        )

    elapsed_min = (time.time() - phase_start) / 60.0
    print(f'[{phase_name}] Termine en {elapsed_min:.2f} minutes')
    return hist, elapsed_min

# %% [markdown]
# ## 4) Execution Strategie 1 (Imagewoof) : BF -> HF
# - Phase A: pre-training sur BF
# - Phase B: fine-tuning sur HF

# %%
model = create_model(num_classes=10)
print('Modele initialise:', model.__class__.__name__)

hist_pre, pretrain_time_min = train_phase(
    model=model,
    train_loader=loader_bf_train,
    val_loader=loader_hf_val,
    epochs=PRETRAIN_EPOCHS,
    lr=LR_PRETRAIN,
    phase_name='Pretrain BF'
)

hist_ft, finetune_time_min = train_phase(
    model=model,
    train_loader=loader_hf_train,
    val_loader=loader_hf_val,
    epochs=FINETUNE_EPOCHS,
    lr=LR_FINETUNE,
    phase_name='Finetune HF'
)
# Out:
# Modele initialise: ResNet
# [Pretrain BF] Epoch 1/10 | Batch 1/127 | loss_batch=2.4305 | 0.06 batch/s | ETA epoch=36.2 min
# [Pretrain BF] Epoch 1/10 | Batch 10/127 | loss_batch=2.0578 | 0.56 batch/s | ETA epoch=3.5 min
# [Pretrain BF] Epoch 1/10 | Batch 20/127 | loss_batch=2.1347 | 1.09 batch/s | ETA epoch=1.6 min
# [Pretrain BF] Epoch 1/10 | Batch 30/127 | loss_batch=2.1880 | 1.57 batch/s | ETA epoch=1.0 min
# [Pretrain BF] Epoch 1/10 | Batch 40/127 | loss_batch=2.0751 | 2.02 batch/s | ETA epoch=0.7 min
# [Pretrain BF] Epoch 1/10 | Batch 50/127 | loss_batch=2.1083 | 2.45 batch/s | ETA epoch=0.5 min
# [Pretrain BF] Epoch 1/10 | Batch 60/127 | loss_batch=2.0943 | 2.85 batch/s | ETA epoch=0.4 min
# [Pretrain BF] Epoch 1/10 | Batch 70/127 | loss_batch=2.0086 | 3.22 batch/s | ETA epoch=0.3 min
# [Pretrain BF] Epoch 1/10 | Batch 80/127 | loss_batch=1.9529 | 3.57 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 1/10 | Batch 90/127 | loss_batch=1.9828 | 3.90 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 1/10 | Batch 100/127 | loss_batch=2.1447 | 4.21 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 1/10 | Batch 110/127 | loss_batch=2.0252 | 4.51 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 1/10 | Batch 120/127 | loss_batch=2.1501 | 4.79 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 1/10 | Batch 127/127 | loss_batch=1.9849 | 3.16 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 1/10 terminee en 0.68 min | train_loss=2.1108 | val_loss=2.1458 | val_acc=26.67%
# [Pretrain BF] Epoch 2/10 | Batch 1/127 | loss_batch=1.8307 | 3.50 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 2/10 | Batch 10/127 | loss_batch=1.8727 | 10.87 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 2/10 | Batch 20/127 | loss_batch=1.9251 | 11.92 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 30/127 | loss_batch=1.7770 | 12.48 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 40/127 | loss_batch=2.0872 | 13.02 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 50/127 | loss_batch=2.0594 | 13.38 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 60/127 | loss_batch=1.8387 | 13.63 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 70/127 | loss_batch=1.8639 | 13.81 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 80/127 | loss_batch=1.9825 | 13.96 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 2/10 | Batch 90/127 | loss_batch=1.7546 | 14.07 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 2/10 | Batch 100/127 | loss_batch=1.7912 | 14.14 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 2/10 | Batch 110/127 | loss_batch=1.8063 | 14.22 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 2/10 | Batch 120/127 | loss_batch=1.7849 | 14.31 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 2/10 | Batch 127/127 | loss_batch=1.8764 | 14.34 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 2/10 terminee en 0.16 min | train_loss=1.8813 | val_loss=2.1508 | val_acc=28.33%
# [Pretrain BF] Epoch 3/10 | Batch 1/127 | loss_batch=1.8475 | 3.55 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 3/10 | Batch 10/127 | loss_batch=1.8738 | 10.75 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 3/10 | Batch 20/127 | loss_batch=1.7573 | 11.94 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 30/127 | loss_batch=1.9012 | 12.26 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 40/127 | loss_batch=1.7964 | 12.53 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 50/127 | loss_batch=1.7193 | 12.71 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 60/127 | loss_batch=1.8619 | 13.06 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 70/127 | loss_batch=1.9061 | 13.27 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 80/127 | loss_batch=1.5990 | 13.35 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 3/10 | Batch 90/127 | loss_batch=1.8341 | 13.39 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 3/10 | Batch 100/127 | loss_batch=1.7153 | 13.43 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 3/10 | Batch 110/127 | loss_batch=1.7825 | 13.51 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 3/10 | Batch 120/127 | loss_batch=1.5526 | 13.57 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 3/10 | Batch 127/127 | loss_batch=1.8205 | 13.64 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 3/10 terminee en 0.17 min | train_loss=1.7384 | val_loss=2.0394 | val_acc=33.89%
# [Pretrain BF] Epoch 4/10 | Batch 1/127 | loss_batch=1.8179 | 3.43 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 4/10 | Batch 10/127 | loss_batch=1.5828 | 10.55 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 4/10 | Batch 20/127 | loss_batch=1.5303 | 12.41 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 30/127 | loss_batch=1.5231 | 13.25 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 40/127 | loss_batch=1.2798 | 13.75 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 50/127 | loss_batch=1.8419 | 14.06 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 60/127 | loss_batch=1.4561 | 14.24 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 70/127 | loss_batch=1.5903 | 14.40 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 80/127 | loss_batch=1.9117 | 14.48 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 4/10 | Batch 90/127 | loss_batch=1.5656 | 14.57 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 4/10 | Batch 100/127 | loss_batch=1.4646 | 14.65 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 4/10 | Batch 110/127 | loss_batch=1.4874 | 14.68 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 4/10 | Batch 120/127 | loss_batch=1.4771 | 14.73 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 4/10 | Batch 127/127 | loss_batch=1.7679 | 14.74 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 4/10 terminee en 0.16 min | train_loss=1.6268 | val_loss=2.1118 | val_acc=31.11%
# [Pretrain BF] Epoch 5/10 | Batch 1/127 | loss_batch=1.7294 | 3.60 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 5/10 | Batch 10/127 | loss_batch=1.5008 | 11.01 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 5/10 | Batch 20/127 | loss_batch=1.5639 | 12.49 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 30/127 | loss_batch=1.5537 | 13.08 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 40/127 | loss_batch=1.4945 | 13.62 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 50/127 | loss_batch=1.5992 | 13.95 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 60/127 | loss_batch=1.6852 | 14.18 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 70/127 | loss_batch=1.5376 | 14.35 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 80/127 | loss_batch=1.4145 | 14.47 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 5/10 | Batch 90/127 | loss_batch=1.3712 | 14.56 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 5/10 | Batch 100/127 | loss_batch=1.3810 | 14.65 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 5/10 | Batch 110/127 | loss_batch=1.3233 | 14.72 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 5/10 | Batch 120/127 | loss_batch=1.9183 | 14.77 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 5/10 | Batch 127/127 | loss_batch=1.4957 | 14.80 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 5/10 terminee en 0.16 min | train_loss=1.5083 | val_loss=2.4222 | val_acc=27.22%
# [Pretrain BF] Epoch 6/10 | Batch 1/127 | loss_batch=1.4932 | 3.62 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 6/10 | Batch 10/127 | loss_batch=1.6243 | 10.57 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 6/10 | Batch 20/127 | loss_batch=1.3157 | 11.57 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 6/10 | Batch 30/127 | loss_batch=1.4105 | 12.49 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 40/127 | loss_batch=1.6674 | 13.10 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 50/127 | loss_batch=1.3986 | 13.51 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 60/127 | loss_batch=1.4711 | 13.78 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 70/127 | loss_batch=1.5206 | 13.98 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 80/127 | loss_batch=1.6922 | 14.12 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 6/10 | Batch 90/127 | loss_batch=1.3053 | 14.20 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 6/10 | Batch 100/127 | loss_batch=1.4219 | 14.27 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 6/10 | Batch 110/127 | loss_batch=1.7262 | 14.31 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 6/10 | Batch 120/127 | loss_batch=1.4286 | 14.40 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 6/10 | Batch 127/127 | loss_batch=1.4700 | 14.46 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 6/10 terminee en 0.16 min | train_loss=1.4073 | val_loss=1.6689 | val_acc=41.67%
# [Pretrain BF] Epoch 7/10 | Batch 1/127 | loss_batch=1.1096 | 3.62 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 7/10 | Batch 10/127 | loss_batch=1.1639 | 11.83 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 7/10 | Batch 20/127 | loss_batch=1.0662 | 13.19 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 30/127 | loss_batch=1.3414 | 13.71 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 40/127 | loss_batch=1.4875 | 14.02 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 50/127 | loss_batch=1.2097 | 14.19 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 60/127 | loss_batch=1.0650 | 14.25 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 70/127 | loss_batch=1.6855 | 14.33 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 80/127 | loss_batch=1.3278 | 14.40 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 7/10 | Batch 90/127 | loss_batch=1.3535 | 14.44 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 7/10 | Batch 100/127 | loss_batch=1.1649 | 14.50 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 7/10 | Batch 110/127 | loss_batch=1.1393 | 14.52 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 7/10 | Batch 120/127 | loss_batch=1.3064 | 14.56 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 7/10 | Batch 127/127 | loss_batch=0.9975 | 14.62 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 7/10 terminee en 0.16 min | train_loss=1.2732 | val_loss=1.8615 | val_acc=39.44%
# [Pretrain BF] Epoch 8/10 | Batch 1/127 | loss_batch=0.9460 | 3.58 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 8/10 | Batch 10/127 | loss_batch=1.1269 | 11.14 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 8/10 | Batch 20/127 | loss_batch=1.1075 | 12.79 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 30/127 | loss_batch=0.7326 | 13.56 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 40/127 | loss_batch=1.3802 | 14.02 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 50/127 | loss_batch=1.0396 | 14.24 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 60/127 | loss_batch=1.0023 | 14.41 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 70/127 | loss_batch=1.1495 | 14.55 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 80/127 | loss_batch=1.1986 | 14.64 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 8/10 | Batch 90/127 | loss_batch=0.8859 | 14.69 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 8/10 | Batch 100/127 | loss_batch=1.0713 | 14.72 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 8/10 | Batch 110/127 | loss_batch=0.9861 | 14.77 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 8/10 | Batch 120/127 | loss_batch=1.1211 | 14.84 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 8/10 | Batch 127/127 | loss_batch=1.2610 | 14.84 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 8/10 terminee en 0.16 min | train_loss=1.1173 | val_loss=1.5378 | val_acc=47.78%
# [Pretrain BF] Epoch 9/10 | Batch 1/127 | loss_batch=0.9445 | 3.53 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 9/10 | Batch 10/127 | loss_batch=0.7910 | 10.70 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 9/10 | Batch 20/127 | loss_batch=0.6861 | 12.45 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 30/127 | loss_batch=0.9026 | 13.31 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 40/127 | loss_batch=0.9437 | 13.71 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 50/127 | loss_batch=0.9712 | 13.94 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 60/127 | loss_batch=1.1019 | 14.10 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 70/127 | loss_batch=1.0287 | 14.20 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 80/127 | loss_batch=0.9204 | 14.25 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 9/10 | Batch 90/127 | loss_batch=0.9806 | 14.37 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 9/10 | Batch 100/127 | loss_batch=0.9390 | 14.48 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 9/10 | Batch 110/127 | loss_batch=1.0217 | 14.55 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 9/10 | Batch 120/127 | loss_batch=0.9899 | 14.61 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 9/10 | Batch 127/127 | loss_batch=0.8999 | 14.66 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 9/10 terminee en 0.16 min | train_loss=0.9225 | val_loss=1.7886 | val_acc=40.56%
# [Pretrain BF] Epoch 10/10 | Batch 1/127 | loss_batch=0.6532 | 3.59 batch/s | ETA epoch=0.6 min
# [Pretrain BF] Epoch 10/10 | Batch 10/127 | loss_batch=0.6796 | 10.50 batch/s | ETA epoch=0.2 min
# [Pretrain BF] Epoch 10/10 | Batch 20/127 | loss_batch=0.5284 | 12.51 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 30/127 | loss_batch=0.6866 | 13.32 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 40/127 | loss_batch=0.5713 | 13.76 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 50/127 | loss_batch=0.5679 | 14.03 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 60/127 | loss_batch=0.8234 | 14.21 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 70/127 | loss_batch=0.7039 | 14.36 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 80/127 | loss_batch=0.8124 | 14.46 batch/s | ETA epoch=0.1 min
# [Pretrain BF] Epoch 10/10 | Batch 90/127 | loss_batch=0.8127 | 14.53 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 10/10 | Batch 100/127 | loss_batch=0.7032 | 14.59 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 10/10 | Batch 110/127 | loss_batch=0.7514 | 14.66 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 10/10 | Batch 120/127 | loss_batch=0.6725 | 14.71 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 10/10 | Batch 127/127 | loss_batch=0.7273 | 14.78 batch/s | ETA epoch=0.0 min
# [Pretrain BF] Epoch 10/10 terminee en 0.16 min | train_loss=0.7253 | val_loss=2.7391 | val_acc=36.67%
# [Pretrain BF] Termine en 2.11 minutes
# [Finetune HF] Epoch 1/10 | Batch 1/12 | loss_batch=1.4452 | 2.09 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 1/10 | Batch 10/12 | loss_batch=1.4848 | 4.93 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 1/10 | Batch 12/12 | loss_batch=1.1563 | 0.71 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 1/10 terminee en 0.29 min | train_loss=1.5253 | val_loss=1.7631 | val_acc=48.33%
# [Finetune HF] Epoch 2/10 | Batch 1/12 | loss_batch=1.0465 | 2.01 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 2/10 | Batch 10/12 | loss_batch=0.7148 | 5.00 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 2/10 | Batch 12/12 | loss_batch=0.9908 | 5.35 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 2/10 terminee en 0.05 min | train_loss=0.9008 | val_loss=1.5736 | val_acc=51.67%
# [Finetune HF] Epoch 3/10 | Batch 1/12 | loss_batch=0.7387 | 2.11 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 3/10 | Batch 10/12 | loss_batch=0.5789 | 5.03 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 3/10 | Batch 12/12 | loss_batch=0.8606 | 5.59 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 3/10 terminee en 0.05 min | train_loss=0.5998 | val_loss=1.4644 | val_acc=51.67%
# [Finetune HF] Epoch 4/10 | Batch 1/12 | loss_batch=0.5275 | 1.54 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 4/10 | Batch 10/12 | loss_batch=0.3771 | 4.95 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 4/10 | Batch 12/12 | loss_batch=0.6775 | 5.20 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 4/10 terminee en 0.05 min | train_loss=0.4369 | val_loss=1.6023 | val_acc=45.00%
# [Finetune HF] Epoch 5/10 | Batch 1/12 | loss_batch=0.3951 | 2.13 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 5/10 | Batch 10/12 | loss_batch=0.2798 | 5.05 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 5/10 | Batch 12/12 | loss_batch=0.9633 | 5.26 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 5/10 terminee en 0.05 min | train_loss=0.2958 | val_loss=1.4960 | val_acc=50.56%
# [Finetune HF] Epoch 6/10 | Batch 1/12 | loss_batch=0.1491 | 2.04 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 6/10 | Batch 10/12 | loss_batch=0.2410 | 4.93 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 6/10 | Batch 12/12 | loss_batch=0.3029 | 5.61 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 6/10 terminee en 0.05 min | train_loss=0.2068 | val_loss=1.6199 | val_acc=51.67%
# [Finetune HF] Epoch 7/10 | Batch 1/12 | loss_batch=0.1282 | 2.17 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 7/10 | Batch 10/12 | loss_batch=0.1180 | 4.73 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 7/10 | Batch 12/12 | loss_batch=0.3077 | 4.93 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 7/10 terminee en 0.05 min | train_loss=0.1392 | val_loss=1.6142 | val_acc=48.89%
# [Finetune HF] Epoch 8/10 | Batch 1/12 | loss_batch=0.1234 | 1.97 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 8/10 | Batch 10/12 | loss_batch=0.0646 | 4.99 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 8/10 | Batch 12/12 | loss_batch=0.1366 | 5.44 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 8/10 terminee en 0.05 min | train_loss=0.0982 | val_loss=1.6171 | val_acc=50.00%
# [Finetune HF] Epoch 9/10 | Batch 1/12 | loss_batch=0.0587 | 2.01 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 9/10 | Batch 10/12 | loss_batch=0.0610 | 4.70 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 9/10 | Batch 12/12 | loss_batch=0.0849 | 4.97 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 9/10 terminee en 0.05 min | train_loss=0.0650 | val_loss=1.6541 | val_acc=50.56%
# [Finetune HF] Epoch 10/10 | Batch 1/12 | loss_batch=0.0419 | 2.05 batch/s | ETA epoch=0.1 min
# [Finetune HF] Epoch 10/10 | Batch 10/12 | loss_batch=0.0481 | 4.74 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 10/10 | Batch 12/12 | loss_batch=0.1650 | 4.99 batch/s | ETA epoch=0.0 min
# [Finetune HF] Epoch 10/10 terminee en 0.05 min | train_loss=0.0548 | val_loss=1.6514 | val_acc=52.22%
# [Finetune HF] Termine en 0.75 minutes

# %% [markdown]
# ## 5) Evaluation finale, cout, sauvegarde et visualisation

# %%
criterion = nn.CrossEntropyLoss()
test_hf_loss, test_hf_acc = evaluate(model, loader_test_hf, criterion)
test_bf_loss, test_bf_acc = evaluate(model, loader_test_bf, criterion)
test_mix_acc = (test_hf_acc + test_bf_acc) / 2.0

cost_pretrain = len(dataset_bf_train) * COST_BF * PRETRAIN_EPOCHS
cost_finetune = len(dataset_hf_train) * COST_HF * FINETUNE_EPOCHS
total_cost = cost_pretrain + cost_finetune
total_time_min = pretrain_time_min + finetune_time_min

results = {
    'strategy': 'transfer_learning_sequentiel',
    'dataset': 'Imagewoof',
    'pipeline': 'BF_pretraining_then_HF_finetuning',
    'pretrain_epochs': PRETRAIN_EPOCHS,
    'finetune_epochs': FINETUNE_EPOCHS,
    'lr_pretrain': LR_PRETRAIN,
    'lr_finetune': LR_FINETUNE,
    'cost_pretrain_CA': int(cost_pretrain),
    'cost_finetune_CA': int(cost_finetune),
    'total_cost_CA': int(total_cost),
    'pretrain_time_min': float(pretrain_time_min),
    'finetune_time_min': float(finetune_time_min),
    'total_time_min': float(total_time_min),
    'test_hf_loss': float(test_hf_loss),
    'test_bf_loss': float(test_bf_loss),
    'accuracy_HF': float(test_hf_acc),
    'accuracy_BF': float(test_bf_acc),
    'accuracy_Mixte': float(test_mix_acc),
    'history_pretrain': hist_pre,
    'history_finetune': hist_ft
}

json_path = os.path.join(RESULTS_DIR, 'results_strategy1_transfer_learning.json')
pth_path = os.path.join(RESULTS_DIR, 'model_strategy1_transfer_learning.pth')
png_path = os.path.join(RESULTS_DIR, 'strategy1_transfer_learning_curves.png')

with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

torch.save(model.state_dict(), pth_path)

print('--- RESULTATS FINAUX (Imagewoof - Strategie 1) ---')
print(f"Test HF    : {test_hf_acc:.2f}%")
print(f"Test BF    : {test_bf_acc:.2f}%")
print(f"Test Mixte : {test_mix_acc:.2f}%")
print(f"Cout total : {total_cost} CA")
print(f"Temps total: {total_time_min:.2f} min")
print('JSON sauve:', json_path)
print('Model sauve:', pth_path)

x_pre = np.arange(1, PRETRAIN_EPOCHS + 1)
x_ft = np.arange(PRETRAIN_EPOCHS + 1, PRETRAIN_EPOCHS + FINETUNE_EPOCHS + 1)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Strategie 1 (BF -> HF) - Imagewoof', fontsize=14)

axes[0].plot(x_pre, hist_pre['train_loss'], marker='o', label='Train loss - Pretrain BF')
axes[0].plot(x_pre, hist_pre['val_loss'], marker='o', linestyle='--', label='Val loss HF - Pretrain BF')
axes[0].plot(x_ft, hist_ft['train_loss'], marker='o', label='Train loss - Finetune HF')
axes[0].plot(x_ft, hist_ft['val_loss'], marker='o', linestyle='--', label='Val loss HF - Finetune HF')
axes[0].axvline(PRETRAIN_EPOCHS + 0.5, color='gray', linestyle=':', label='Transition BF -> HF')
axes[0].set_title('Evolution de la loss')
axes[0].set_xlabel('Epoch globale')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)
axes[0].legend(fontsize=8)

axes[1].plot(x_pre, hist_pre['val_acc'], marker='o', label='Val acc HF - Pretrain BF')
axes[1].plot(x_ft, hist_ft['val_acc'], marker='o', label='Val acc HF - Finetune HF')
axes[1].axvline(PRETRAIN_EPOCHS + 0.5, color='gray', linestyle=':', label='Transition BF -> HF')
axes[1].set_title('Evolution de la precision (validation HF)')
axes[1].set_xlabel('Epoch globale')
axes[1].set_ylabel('Accuracy (%)')
axes[1].grid(alpha=0.3)
axes[1].legend(fontsize=8)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig(png_path, dpi=180, bbox_inches='tight')
plt.show()
print('Figure sauvee:', png_path)
# Out:
# --- RESULTATS FINAUX (Imagewoof - Strategie 1) ---
# Test HF    : 52.84%
# Test BF    : 44.67%
# Test Mixte : 48.75%
# Cout total : 153160 CA
# Temps total: 2.87 min
# JSON sauve: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/results_strategy1_transfer_learning.json
# Model sauve: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/model_strategy1_transfer_learning.pth
# Figure sauvee: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/strategy1_transfer_learning_curves.png

# %% [markdown]
# ## 6) Comparaison avec les baselines Imagewoof
# Charge les JSON deja produits dans `results/Imagewoof/` (baselines + strategie 1).

# %%
baseline_files = {
    'BL 1(HF)': 'results_baseline_HF.json',
    'BL 2(BF)': 'results_baseline_BF.json',
    'BL 3(MIXTE)': 'results_baseline_MIXTE.json',
    'Strategie 1(BF->HF)': 'results_strategy1_transfer_learning.json'
}

rows = []
for name, fn in baseline_files.items():
    p = os.path.join(RESULTS_DIR, fn)
    if os.path.exists(p):
        with open(p, 'r', encoding='utf-8') as f:
            d = json.load(f)
        rows.append((
            name,
            d.get('accuracy_HF', np.nan),
            d.get('accuracy_BF', np.nan),
            d.get('accuracy_Mixte', np.nan),
            d.get('total_cost_CA', np.nan),
            d.get('training_time_sec', np.nan) / 60.0 if 'training_time_sec' in d else d.get('total_time_min', np.nan)
        ))

if not rows:
    print('Aucun fichier JSON trouve pour la comparaison dans', RESULTS_DIR)
else:
    header = f"{'Modele (Imagewoof)':<24} {'HF%':>8} {'BF%':>8} {'Mixte%':>10} {'Cout(CA)':>12} {'Temps(min)':>12}"
    print(header)
    print('-' * len(header))
    for r in rows:
        print(f"{r[0]:<24} {r[1]:>8.2f} {r[2]:>8.2f} {r[3]:>10.2f} {r[4]:>12.0f} {r[5]:>12.2f}")
# Out:
# Modele (Imagewoof)            HF%      BF%     Mixte%     Cout(CA)   Temps(min)
# -------------------------------------------------------------------------------
# BL 1(HF)                    26.14    25.38      25.76       179800         0.95
# BL 2(BF)                    44.21    48.94      46.58       162520         2.86
# BL 3(MIXTE)                 51.82    48.97      50.39       342320         3.72
# Strategie 1(BF->HF)         52.84    44.67      48.75       153160         2.87
