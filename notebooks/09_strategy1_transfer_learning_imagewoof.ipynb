# %% [markdown]
# # Partie 4 - Etape 1 (Imagewoof) : Transfer Learning Sequentiel
#
# Reprise stricte du protocole du notebook `04_strategy1_transfer_learning.ipynb` mais sur le **dataset Imagewoof** preparé par `07_Prepare_New_Dataset.ipynb`.
#
# ## Objectif
# - Phase A: pre-entrainer un ResNet-18 sur le domaine BF (images degradees).
# - Phase B: faire un fine-tuning sur le domaine HF (images propres).
# - Evaluer ensuite sur test HF, test BF et precision mixte.
#
# ## Sorties attendues
# - Metriques finales (HF, BF, Mixte, temps, cout) pour Imagewoof.
# - Courbes de loss/accuracy par phase.
# - Sauvegarde JSON + poids du modele final dans `results/Imagewoof/`.

# %%
import os
import json
import time
import random
import shutil
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt

try:
    import wandb
    _WANDB_AVAILABLE = True
except ImportError:
    _WANDB_AVAILABLE = False
    print("⚠️ wandb non installé : pip install wandb pour activer le tracking.")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.benchmark = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Appareil: {device}')
# Out:
# Appareil: cuda

# %% [markdown]
# ## 1) Montage Drive et chemins de travail (Imagewoof)
# Ce bloc supporte a la fois Colab et un execution locale. Differences avec `04` :
# - `zip_source` pointe vers le ZIP Imagewoof,
# - les fallbacks Drive cherchent dans le dossier Imagewoof,
# - `RESULTS_DIR` ecrit dans le sous-dossier `results/Imagewoof/` pour ne pas ecraser les resultats Animals-10.

# %%
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive', force_remount=True)

    local_base = '/content/processed_multifidelity'
    zip_source = '/content/drive/MyDrive/UTBM_PF22/datasets/Imagewoof/dataset_multifidelity.zip'
    drive_base_candidates = [
        '/content/drive/MyDrive/UTBM_PF22/datasets/Imagewoof/processed_multifidelity',
        '/content/drive/MyDrive/UTBM_PF22/results/datasets/Imagewoof/processed_multifidelity',
    ]

    if os.path.exists(local_base):
        print('Dataset deja present sur SSD local, reutilisation.')
        BASE_DIR = local_base
    else:
        if os.path.exists(zip_source):
            print('Extraction du zip dataset Imagewoof vers SSD local...')
            start = time.time()
            shutil.copy2(zip_source, '/content/dataset_multifidelity.zip')
            import zipfile
            with zipfile.ZipFile('/content/dataset_multifidelity.zip', 'r') as zip_ref:
                zip_ref.extractall('/content/')
            os.remove('/content/dataset_multifidelity.zip')
            print(f'Dataset extrait sur SSD en {time.time()-start:.2f}s')
            BASE_DIR = local_base if os.path.exists(local_base) else None
        else:
            BASE_DIR = None

        if BASE_DIR is None:
            drive_base = next((p for p in drive_base_candidates if os.path.exists(p)), None)
            if drive_base is None:
                raise FileNotFoundError(
                    'Aucun dataset Imagewoof trouve. Chemins testes: '
                    + ' | '.join([zip_source] + drive_base_candidates)
                )
            print('SSD indisponible, fallback vers le dossier Drive deja prepare.')
            BASE_DIR = drive_base

    RESULTS_DIR = '/content/drive/MyDrive/UTBM_PF22/results/Imagewoof'
else:
    candidate_base_dirs = [
        '../data/processed_multifidelity',
        './data/processed_multifidelity',
        'data/processed_multifidelity',
    ]
    BASE_DIR = next((p for p in candidate_base_dirs if os.path.exists(p)), None)
    if BASE_DIR is None:
        raise FileNotFoundError(
            'Aucun dossier processed_multifidelity trouve. Chemins testes: '
            + ' | '.join(candidate_base_dirs)
        )
    RESULTS_DIR = '../results/Imagewoof'

os.makedirs(RESULTS_DIR, exist_ok=True)
print('BASE_DIR selectionne =', BASE_DIR)
print('RESULTS_DIR         =', RESULTS_DIR)
# Out:
# Mounted at /content/drive
# Dataset deja present sur SSD local, reutilisation.
# BASE_DIR selectionne = /content/processed_multifidelity
# RESULTS_DIR         = /content/drive/MyDrive/UTBM_PF22/results/Imagewoof

# %% [markdown]
# ## 2) Datasets et transforms
# On reprend le meme protocole de degradation que les baselines pour le test BF.
#
# Imagewoof a 10 classes (`num_classes=10`), comme Animals-10, donc l'architecture du modele est inchangee.

# %%
COST_HF = 10
COST_BF = 1
BATCH_SIZE = 64
NUM_WORKERS = 2 if '/content/processed_multifidelity' in str(BASE_DIR) else 0
PRETRAIN_EPOCHS = 10
FINETUNE_EPOCHS = 10
LR_PRETRAIN = 1e-3
LR_FINETUNE = 3e-4
HF_TRAIN_RATIO = 0.8

class AddDegradationTransform:
    """Degrade un tenseur image pour simuler le domaine BF."""
    def __call__(self, img_tensor):
        h, w = img_tensor.shape[1], img_tensor.shape[2]
        img_degraded = transforms.functional.resize(img_tensor, (64, 64), antialias=True)
        img_degraded = transforms.functional.resize(img_degraded, (h, w), antialias=True)
        noise = torch.randn_like(img_degraded) * 0.15
        img_noisy = img_degraded + noise
        return torch.clamp(img_noisy, 0, 1)

transform_standard = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_bf_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    AddDegradationTransform(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

required_dirs = [
    os.path.join(BASE_DIR, 'train', 'BF'),
    os.path.join(BASE_DIR, 'train', 'HF'),
    os.path.join(BASE_DIR, 'test'),
]
missing = [p for p in required_dirs if not os.path.isdir(p)]
if missing:
    raise FileNotFoundError(
        'Structure dataset invalide. Dossiers manquants: ' + ' | '.join(missing)
    )

dataset_bf_train = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/BF'), transform=transform_standard)
dataset_hf_full = datasets.ImageFolder(os.path.join(BASE_DIR, 'train/HF'), transform=transform_standard)
dataset_test_hf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_standard)
dataset_test_bf = datasets.ImageFolder(os.path.join(BASE_DIR, 'test'), transform=transform_bf_test)

hf_train_size = int(HF_TRAIN_RATIO * len(dataset_hf_full))
hf_val_size = len(dataset_hf_full) - hf_train_size
dataset_hf_train, dataset_hf_val = random_split(
    dataset_hf_full,
    [hf_train_size, hf_val_size],
    generator=torch.Generator().manual_seed(SEED)
)

loader_bf_train = DataLoader(dataset_bf_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
loader_hf_train = DataLoader(dataset_hf_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
loader_hf_val = DataLoader(dataset_hf_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_hf = DataLoader(dataset_test_hf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
loader_test_bf = DataLoader(dataset_test_bf, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f'Train BF: {len(dataset_bf_train)} images')
print(f'Train HF (fine-tune): {len(dataset_hf_train)} images')
print(f'Val HF: {len(dataset_hf_val)} images')
print(f'Test HF/BF: {len(dataset_test_hf)} images')
print(f'NUM_WORKERS utilise: {NUM_WORKERS}')
print(f'Nb batches BF: {len(loader_bf_train)} | Nb batches HF: {len(loader_hf_train)}')
print(f'Classes: {dataset_hf_full.classes}')
# Out:
# Train BF: 8126 images
# Train HF (fine-tune): 719 images
# Val HF: 180 images
# Test HF/BF: 3929 images
# NUM_WORKERS utilise: 2
# Nb batches BF: 127 | Nb batches HF: 12
# Classes: ['n02086240', 'n02087394', 'n02088364', 'n02089973', 'n02093754', 'n02096294', 'n02099601', 'n02105641', 'n02111889', 'n02115641']

# %% [markdown]
# ## 3) Utilitaires de modelisation
# - Initialisation ResNet-18 from scratch
# - Boucle d'entrainement AMP
# - Evaluation par domaine

# %%
def create_model(num_classes=10):
    model = models.resnet18(weights=None)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)
            total_loss += loss.item() * x.size(0)
            total_correct += (logits.argmax(dim=1) == y).sum().item()
            total_samples += x.size(0)
    return total_loss / total_samples, 100.0 * total_correct / total_samples

def make_grad_scaler():
    try:
        return GradScaler('cuda', enabled=(device.type == 'cuda'))
    except TypeError:
        return GradScaler(enabled=(device.type == 'cuda'))

def train_phase(model, train_loader, val_loader, epochs, lr, phase_name,
                use_wandb=False, cost_per_epoch_CA=0,
                global_epoch_offset=0, cumulative_cost_start=0):
    """Entraîne `model` pendant `epochs`. Si `use_wandb` est True, logge à W&B
    train_loss / val_loss / val_acc / cumulative_cost_CA, avec un epoch global
    qui inclut `global_epoch_offset` pour avoir une courbe continue Pretrain->Finetune.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = make_grad_scaler()

    hist = {'train_loss': [], 'val_loss': [], 'val_acc': []}
    phase_start = time.time()
    log_every = 10

    for epoch in range(1, epochs + 1):
        model.train()
        running_loss = 0.0
        total = 0
        epoch_start = time.time()

        for batch_idx, (x, y) in enumerate(train_loader, start=1):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad(set_to_none=True)

            with autocast(device_type='cuda', enabled=(device.type == 'cuda')):
                logits = model(x)
                loss = criterion(logits, y)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item() * x.size(0)
            total += x.size(0)

            if batch_idx % log_every == 0 or batch_idx == 1 or batch_idx == len(train_loader):
                elapsed = time.time() - epoch_start
                bps = batch_idx / elapsed if elapsed > 0 else 0.0
                eta_sec = (len(train_loader) - batch_idx) / bps if bps > 0 else 0.0
                print(
                    f'[{phase_name}] Epoch {epoch}/{epochs} | Batch {batch_idx}/{len(train_loader)} | '
                    f'loss_batch={loss.item():.4f} | {bps:.2f} batch/s | ETA epoch={eta_sec/60:.1f} min'
                )

        train_loss = running_loss / total
        val_loss, val_acc = evaluate(model, val_loader, criterion)
        epoch_min = (time.time() - epoch_start) / 60.0

        hist['train_loss'].append(train_loss)
        hist['val_loss'].append(val_loss)
        hist['val_acc'].append(val_acc)

        print(
            f'[{phase_name}] Epoch {epoch}/{epochs} terminee en {epoch_min:.2f} min | '
            f'train_loss={train_loss:.4f} | val_loss={val_loss:.4f} | val_acc={val_acc:.2f}%'
        )

        if use_wandb and _WANDB_AVAILABLE:
            cumulative_cost = cumulative_cost_start + cost_per_epoch_CA * epoch
            wandb.log({
                "epoch": global_epoch_offset + epoch,
                "phase": phase_name,
                "train/loss": train_loss,
                "val/loss": val_loss,
                "val/accuracy": val_acc,
                "cumulative_cost_CA": cumulative_cost,
                f"{phase_name}/train_loss": train_loss,
                f"{phase_name}/val_loss": val_loss,
                f"{phase_name}/val_accuracy": val_acc,
            })

    elapsed_min = (time.time() - phase_start) / 60.0
    print(f'[{phase_name}] Termine en {elapsed_min:.2f} minutes')
    return hist, elapsed_min

# %% [markdown]
# ## 4) Execution Strategie 1 (Imagewoof) : BF -> HF
# - Phase A: pre-training sur BF
# - Phase B: fine-tuning sur HF

# %%
# --- Configuration W&B ---
USE_WANDB = True
DATASET_NAME = "Imagewoof"
WANDB_PROJECT = "PF22-MultiFidelity"
WANDB_RUN_NAME = "Strategie1_TransferLearning"

if USE_WANDB and _WANDB_AVAILABLE:
    wandb.init(
        project=WANDB_PROJECT,
        name=WANDB_RUN_NAME,
        tags=["strategy1", "transfer_learning", DATASET_NAME],
        reinit=True,
        config={
            "strategy": "transfer_learning_sequentiel",
            "pipeline": "BF_pretraining_then_HF_finetuning",
            "dataset": DATASET_NAME,
            "architecture": "resnet18",
            "weights_init": "from_scratch",
            "num_classes": 10,
            "input_size": 224,
            "batch_size": BATCH_SIZE,
            "pretrain_epochs": PRETRAIN_EPOCHS,
            "finetune_epochs": FINETUNE_EPOCHS,
            "lr_pretrain": LR_PRETRAIN,
            "lr_finetune": LR_FINETUNE,
            "hf_train_ratio": HF_TRAIN_RATIO,
            "optimizer": "Adam",
            "loss": "CrossEntropyLoss",
            "amp_fp16": True,
            "cost_HF_per_image": COST_HF,
            "cost_BF_per_image": COST_BF,
            "train_size_BF": len(dataset_bf_train),
            "train_size_HF": len(dataset_hf_train),
            "val_size_HF": len(dataset_hf_val),
            "test_size": len(dataset_test_hf),
        }
    )

model = create_model(num_classes=10)
print('Modele initialise:', model.__class__.__name__)

# Coûts par phase (utilisés pour le coût cumulé W&B)
cost_per_epoch_pretrain = len(dataset_bf_train) * COST_BF
cost_per_epoch_finetune = len(dataset_hf_train) * COST_HF
cumulative_after_pretrain = cost_per_epoch_pretrain * PRETRAIN_EPOCHS

# Phase A : pré-entraînement BF
hist_pre, pretrain_time_min = train_phase(
    model=model,
    train_loader=loader_bf_train,
    val_loader=loader_hf_val,
    epochs=PRETRAIN_EPOCHS,
    lr=LR_PRETRAIN,
    phase_name='Pretrain_BF',
    use_wandb=USE_WANDB,
    cost_per_epoch_CA=cost_per_epoch_pretrain,
    global_epoch_offset=0,
    cumulative_cost_start=0,
)

# Phase B : fine-tuning HF
hist_ft, finetune_time_min = train_phase(
    model=model,
    train_loader=loader_hf_train,
    val_loader=loader_hf_val,
    epochs=FINETUNE_EPOCHS,
    lr=LR_FINETUNE,
    phase_name='Finetune_HF',
    use_wandb=USE_WANDB,
    cost_per_epoch_CA=cost_per_epoch_finetune,
    global_epoch_offset=PRETRAIN_EPOCHS,
    cumulative_cost_start=cumulative_after_pretrain,
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: ivannvasic05 (ivannvasic05-utbm) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260430_103647-zuc2bwtw</code>
# Syncing run <strong><a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/zuc2bwtw' target="_blank">Strategie1_TransferLearning</a></strong> to <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity</a>
#  View run at <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/zuc2bwtw' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/zuc2bwtw</a>
# Modele initialise: ResNet
# [Pretrain_BF] Epoch 1/10 | Batch 1/127 | loss_batch=2.4307 | 0.76 batch/s | ETA epoch=2.8 min
# [Pretrain_BF] Epoch 1/10 | Batch 10/127 | loss_batch=2.1758 | 6.73 batch/s | ETA epoch=0.3 min
# [Pretrain_BF] Epoch 1/10 | Batch 20/127 | loss_batch=2.2975 | 11.71 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 1/10 | Batch 30/127 | loss_batch=2.2345 | 15.56 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 1/10 | Batch 40/127 | loss_batch=2.0446 | 18.58 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 1/10 | Batch 50/127 | loss_batch=2.1375 | 21.03 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 1/10 | Batch 60/127 | loss_batch=2.0519 | 23.06 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 70/127 | loss_batch=1.9751 | 24.75 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 80/127 | loss_batch=1.9376 | 26.20 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 90/127 | loss_batch=2.0264 | 27.37 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 100/127 | loss_batch=2.0239 | 28.51 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 110/127 | loss_batch=1.9829 | 29.49 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 120/127 | loss_batch=2.2014 | 30.35 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 | Batch 127/127 | loss_batch=1.9432 | 25.57 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 1/10 terminee en 0.09 min | train_loss=2.1113 | val_loss=2.0723 | val_acc=22.22%
# [Pretrain_BF] Epoch 2/10 | Batch 1/127 | loss_batch=1.7907 | 8.90 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 2/10 | Batch 10/127 | loss_batch=1.8790 | 30.15 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 2/10 | Batch 20/127 | loss_batch=1.9488 | 35.00 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 2/10 | Batch 30/127 | loss_batch=1.8107 | 36.24 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 40/127 | loss_batch=2.0529 | 36.79 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 50/127 | loss_batch=1.9578 | 37.10 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 60/127 | loss_batch=1.8894 | 37.15 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 70/127 | loss_batch=1.9436 | 37.21 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 80/127 | loss_batch=2.0122 | 37.31 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 90/127 | loss_batch=1.7252 | 37.44 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 100/127 | loss_batch=1.7961 | 37.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 110/127 | loss_batch=1.7759 | 38.58 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 120/127 | loss_batch=1.7857 | 39.03 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 | Batch 127/127 | loss_batch=1.9187 | 39.42 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 2/10 terminee en 0.06 min | train_loss=1.8814 | val_loss=2.1282 | val_acc=28.33%
# [Pretrain_BF] Epoch 3/10 | Batch 1/127 | loss_batch=1.7950 | 9.13 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 3/10 | Batch 10/127 | loss_batch=1.9544 | 30.64 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 3/10 | Batch 20/127 | loss_batch=1.7012 | 34.04 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 3/10 | Batch 30/127 | loss_batch=1.8928 | 35.06 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 40/127 | loss_batch=1.8237 | 35.60 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 50/127 | loss_batch=1.7907 | 35.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 60/127 | loss_batch=1.8625 | 36.36 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 70/127 | loss_batch=1.8943 | 36.75 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 80/127 | loss_batch=1.6059 | 36.99 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 90/127 | loss_batch=1.8528 | 37.17 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 100/127 | loss_batch=1.7511 | 37.39 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 110/127 | loss_batch=1.7595 | 37.48 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 120/127 | loss_batch=1.5086 | 37.62 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 | Batch 127/127 | loss_batch=1.7456 | 37.77 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 3/10 terminee en 0.06 min | train_loss=1.7344 | val_loss=1.7890 | val_acc=40.00%
# [Pretrain_BF] Epoch 4/10 | Batch 1/127 | loss_batch=1.8993 | 9.03 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 4/10 | Batch 10/127 | loss_batch=1.6717 | 31.22 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 4/10 | Batch 20/127 | loss_batch=1.5354 | 36.39 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 30/127 | loss_batch=1.4833 | 38.83 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 40/127 | loss_batch=1.2563 | 39.97 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 50/127 | loss_batch=1.8721 | 40.68 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 60/127 | loss_batch=1.5222 | 41.25 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 70/127 | loss_batch=1.6527 | 41.63 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 80/127 | loss_batch=1.8858 | 41.89 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 90/127 | loss_batch=1.6557 | 42.07 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 100/127 | loss_batch=1.4551 | 42.20 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 110/127 | loss_batch=1.3834 | 42.32 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 120/127 | loss_batch=1.3877 | 42.46 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 | Batch 127/127 | loss_batch=1.7619 | 42.42 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 4/10 terminee en 0.06 min | train_loss=1.6294 | val_loss=2.0864 | val_acc=30.00%
# [Pretrain_BF] Epoch 5/10 | Batch 1/127 | loss_batch=1.6547 | 9.06 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 5/10 | Batch 10/127 | loss_batch=1.6020 | 31.61 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 5/10 | Batch 20/127 | loss_batch=1.5083 | 36.73 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 30/127 | loss_batch=1.5840 | 38.98 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 40/127 | loss_batch=1.5460 | 40.18 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 50/127 | loss_batch=1.6823 | 40.89 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 60/127 | loss_batch=1.5590 | 41.39 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 70/127 | loss_batch=1.5190 | 41.77 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 80/127 | loss_batch=1.4640 | 42.05 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 90/127 | loss_batch=1.3303 | 42.31 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 100/127 | loss_batch=1.3176 | 42.46 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 110/127 | loss_batch=1.3127 | 42.59 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 120/127 | loss_batch=1.8077 | 42.73 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 | Batch 127/127 | loss_batch=1.4781 | 42.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 5/10 terminee en 0.06 min | train_loss=1.5083 | val_loss=2.5541 | val_acc=28.33%
# [Pretrain_BF] Epoch 6/10 | Batch 1/127 | loss_batch=1.5738 | 9.05 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 6/10 | Batch 10/127 | loss_batch=1.6629 | 29.80 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 6/10 | Batch 20/127 | loss_batch=1.3216 | 32.87 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 6/10 | Batch 30/127 | loss_batch=1.3841 | 35.30 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 40/127 | loss_batch=1.5136 | 37.55 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 50/127 | loss_batch=1.3629 | 38.92 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 60/127 | loss_batch=1.4061 | 39.59 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 70/127 | loss_batch=1.5388 | 40.32 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 80/127 | loss_batch=1.6455 | 40.85 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 90/127 | loss_batch=1.2233 | 41.28 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 100/127 | loss_batch=1.3906 | 41.69 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 110/127 | loss_batch=1.7782 | 41.93 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 120/127 | loss_batch=1.3852 | 42.19 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 | Batch 127/127 | loss_batch=1.4049 | 42.28 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 6/10 terminee en 0.06 min | train_loss=1.4060 | val_loss=1.6285 | val_acc=42.78%
# [Pretrain_BF] Epoch 7/10 | Batch 1/127 | loss_batch=1.0410 | 9.23 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 7/10 | Batch 10/127 | loss_batch=1.1089 | 30.49 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 7/10 | Batch 20/127 | loss_batch=1.0412 | 34.05 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 7/10 | Batch 30/127 | loss_batch=1.2433 | 35.53 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 40/127 | loss_batch=1.4920 | 36.15 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 50/127 | loss_batch=1.1752 | 36.64 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 60/127 | loss_batch=1.0708 | 36.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 70/127 | loss_batch=1.5471 | 37.18 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 80/127 | loss_batch=1.2800 | 37.19 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 90/127 | loss_batch=1.3041 | 37.74 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 100/127 | loss_batch=1.1623 | 38.40 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 110/127 | loss_batch=1.1833 | 38.94 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 120/127 | loss_batch=1.3152 | 39.15 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 | Batch 127/127 | loss_batch=1.0350 | 38.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 7/10 terminee en 0.06 min | train_loss=1.2687 | val_loss=1.8941 | val_acc=38.89%
# [Pretrain_BF] Epoch 8/10 | Batch 1/127 | loss_batch=1.0120 | 9.28 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 8/10 | Batch 10/127 | loss_batch=1.1909 | 30.42 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 8/10 | Batch 20/127 | loss_batch=1.1469 | 36.27 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 30/127 | loss_batch=0.8358 | 38.40 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 40/127 | loss_batch=1.2500 | 39.73 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 50/127 | loss_batch=1.0951 | 40.60 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 60/127 | loss_batch=1.0121 | 41.50 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 70/127 | loss_batch=1.2982 | 41.69 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 80/127 | loss_batch=1.1589 | 42.09 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 90/127 | loss_batch=0.9336 | 42.40 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 100/127 | loss_batch=1.0907 | 42.66 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 110/127 | loss_batch=1.0737 | 42.82 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 120/127 | loss_batch=1.0325 | 42.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 | Batch 127/127 | loss_batch=1.2863 | 42.92 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 8/10 terminee en 0.06 min | train_loss=1.1274 | val_loss=1.5534 | val_acc=46.11%
# [Pretrain_BF] Epoch 9/10 | Batch 1/127 | loss_batch=0.9213 | 9.23 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 9/10 | Batch 10/127 | loss_batch=0.7611 | 30.87 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 9/10 | Batch 20/127 | loss_batch=0.6829 | 36.37 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 30/127 | loss_batch=0.8239 | 38.59 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 40/127 | loss_batch=0.9164 | 39.84 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 50/127 | loss_batch=0.8715 | 40.59 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 60/127 | loss_batch=1.2414 | 41.18 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 70/127 | loss_batch=0.9207 | 41.57 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 80/127 | loss_batch=0.8055 | 41.92 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 90/127 | loss_batch=1.0347 | 42.22 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 100/127 | loss_batch=0.9464 | 42.45 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 110/127 | loss_batch=1.0267 | 42.68 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 120/127 | loss_batch=1.1278 | 42.83 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 | Batch 127/127 | loss_batch=0.9335 | 42.83 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 9/10 terminee en 0.06 min | train_loss=0.9235 | val_loss=1.8546 | val_acc=42.22%
# [Pretrain_BF] Epoch 10/10 | Batch 1/127 | loss_batch=0.6855 | 9.06 batch/s | ETA epoch=0.2 min
# [Pretrain_BF] Epoch 10/10 | Batch 10/127 | loss_batch=0.7199 | 31.53 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 10/10 | Batch 20/127 | loss_batch=0.4894 | 34.06 batch/s | ETA epoch=0.1 min
# [Pretrain_BF] Epoch 10/10 | Batch 30/127 | loss_batch=0.6524 | 36.90 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 40/127 | loss_batch=0.6592 | 38.74 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 50/127 | loss_batch=0.5629 | 39.95 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 60/127 | loss_batch=0.7880 | 40.84 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 70/127 | loss_batch=0.6276 | 41.49 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 80/127 | loss_batch=0.9168 | 41.98 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 90/127 | loss_batch=1.0467 | 42.39 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 100/127 | loss_batch=0.7769 | 42.73 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 110/127 | loss_batch=0.7720 | 42.93 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 120/127 | loss_batch=0.7970 | 43.07 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 | Batch 127/127 | loss_batch=0.6863 | 43.28 batch/s | ETA epoch=0.0 min
# [Pretrain_BF] Epoch 10/10 terminee en 0.05 min | train_loss=0.7225 | val_loss=2.6979 | val_acc=35.00%
# [Pretrain_BF] Termine en 0.60 minutes
# [Finetune_HF] Epoch 1/10 | Batch 1/12 | loss_batch=1.3620 | 4.98 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 1/10 | Batch 10/12 | loss_batch=1.3713 | 11.95 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 1/10 | Batch 12/12 | loss_batch=0.9244 | 6.07 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 1/10 terminee en 0.04 min | train_loss=1.5271 | val_loss=1.7234 | val_acc=46.11%
# [Finetune_HF] Epoch 2/10 | Batch 1/12 | loss_batch=1.1675 | 4.86 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 2/10 | Batch 10/12 | loss_batch=0.7735 | 12.18 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 2/10 | Batch 12/12 | loss_batch=1.1025 | 13.37 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 2/10 terminee en 0.02 min | train_loss=0.9239 | val_loss=1.6017 | val_acc=46.11%
# [Finetune_HF] Epoch 3/10 | Batch 1/12 | loss_batch=0.7526 | 5.26 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 3/10 | Batch 10/12 | loss_batch=0.5818 | 11.87 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 3/10 | Batch 12/12 | loss_batch=0.6656 | 13.62 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 3/10 terminee en 0.02 min | train_loss=0.6197 | val_loss=1.5474 | val_acc=52.78%
# [Finetune_HF] Epoch 4/10 | Batch 1/12 | loss_batch=0.6239 | 3.67 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 4/10 | Batch 10/12 | loss_batch=0.3932 | 12.23 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 4/10 | Batch 12/12 | loss_batch=0.6343 | 12.74 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 4/10 terminee en 0.02 min | train_loss=0.4477 | val_loss=1.6027 | val_acc=48.33%
# [Finetune_HF] Epoch 5/10 | Batch 1/12 | loss_batch=0.4082 | 5.30 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 5/10 | Batch 10/12 | loss_batch=0.3522 | 12.01 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 5/10 | Batch 12/12 | loss_batch=0.7494 | 13.32 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 5/10 terminee en 0.02 min | train_loss=0.3023 | val_loss=1.5580 | val_acc=51.11%
# [Finetune_HF] Epoch 6/10 | Batch 1/12 | loss_batch=0.1500 | 5.05 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 6/10 | Batch 10/12 | loss_batch=0.2202 | 11.96 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 6/10 | Batch 12/12 | loss_batch=0.3661 | 13.66 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 6/10 terminee en 0.02 min | train_loss=0.2024 | val_loss=1.6585 | val_acc=48.33%
# [Finetune_HF] Epoch 7/10 | Batch 1/12 | loss_batch=0.1263 | 5.30 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 7/10 | Batch 10/12 | loss_batch=0.1224 | 11.68 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 7/10 | Batch 12/12 | loss_batch=0.3011 | 12.17 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 7/10 terminee en 0.02 min | train_loss=0.1347 | val_loss=1.6219 | val_acc=50.56%
# [Finetune_HF] Epoch 8/10 | Batch 1/12 | loss_batch=0.1130 | 4.78 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 8/10 | Batch 10/12 | loss_batch=0.0656 | 12.31 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 8/10 | Batch 12/12 | loss_batch=0.0965 | 13.35 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 8/10 terminee en 0.02 min | train_loss=0.0935 | val_loss=1.6714 | val_acc=50.00%
# [Finetune_HF] Epoch 9/10 | Batch 1/12 | loss_batch=0.0589 | 5.08 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 9/10 | Batch 10/12 | loss_batch=0.0549 | 11.59 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 9/10 | Batch 12/12 | loss_batch=0.0816 | 12.24 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 9/10 terminee en 0.02 min | train_loss=0.0623 | val_loss=1.6988 | val_acc=51.11%
# [Finetune_HF] Epoch 10/10 | Batch 1/12 | loss_batch=0.0474 | 4.99 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 10/10 | Batch 10/12 | loss_batch=0.0444 | 11.51 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 10/10 | Batch 12/12 | loss_batch=0.1459 | 12.17 batch/s | ETA epoch=0.0 min
# [Finetune_HF] Epoch 10/10 terminee en 0.02 min | train_loss=0.0505 | val_loss=1.7075 | val_acc=50.00%
# [Finetune_HF] Termine en 0.23 minutes

# %% [markdown]
# ## 5) Evaluation finale, cout, sauvegarde et visualisation

# %%
criterion = nn.CrossEntropyLoss()
test_hf_loss, test_hf_acc = evaluate(model, loader_test_hf, criterion)
test_bf_loss, test_bf_acc = evaluate(model, loader_test_bf, criterion)
test_mix_acc = (test_hf_acc + test_bf_acc) / 2.0

cost_pretrain = len(dataset_bf_train) * COST_BF * PRETRAIN_EPOCHS
cost_finetune = len(dataset_hf_train) * COST_HF * FINETUNE_EPOCHS
total_cost = cost_pretrain + cost_finetune
total_time_min = pretrain_time_min + finetune_time_min

results = {
    'strategy': 'transfer_learning_sequentiel',
    'dataset': 'Imagewoof',
    'pipeline': 'BF_pretraining_then_HF_finetuning',
    'pretrain_epochs': PRETRAIN_EPOCHS,
    'finetune_epochs': FINETUNE_EPOCHS,
    'lr_pretrain': LR_PRETRAIN,
    'lr_finetune': LR_FINETUNE,
    'cost_pretrain_CA': int(cost_pretrain),
    'cost_finetune_CA': int(cost_finetune),
    'total_cost_CA': int(total_cost),
    'pretrain_time_min': float(pretrain_time_min),
    'finetune_time_min': float(finetune_time_min),
    'total_time_min': float(total_time_min),
    'test_hf_loss': float(test_hf_loss),
    'test_bf_loss': float(test_bf_loss),
    'accuracy_HF': float(test_hf_acc),
    'accuracy_BF': float(test_bf_acc),
    'accuracy_Mixte': float(test_mix_acc),
    'history_pretrain': hist_pre,
    'history_finetune': hist_ft
}

json_path = os.path.join(RESULTS_DIR, 'results_strategy1_transfer_learning.json')
pth_path = os.path.join(RESULTS_DIR, 'model_strategy1_transfer_learning.pth')
png_path = os.path.join(RESULTS_DIR, 'strategy1_transfer_learning_curves.png')

with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

torch.save(model.state_dict(), pth_path)

print('--- RESULTATS FINAUX (Imagewoof - Strategie 1) ---')
print(f"Test HF    : {test_hf_acc:.2f}%")
print(f"Test BF    : {test_bf_acc:.2f}%")
print(f"Test Mixte : {test_mix_acc:.2f}%")
print(f"Cout total : {total_cost} CA")
print(f"Temps total: {total_time_min:.2f} min")
print('JSON sauve:', json_path)
print('Model sauve:', pth_path)

x_pre = np.arange(1, PRETRAIN_EPOCHS + 1)
x_ft = np.arange(PRETRAIN_EPOCHS + 1, PRETRAIN_EPOCHS + FINETUNE_EPOCHS + 1)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Strategie 1 (BF -> HF) - Imagewoof', fontsize=14)

axes[0].plot(x_pre, hist_pre['train_loss'], marker='o', label='Train loss - Pretrain BF')
axes[0].plot(x_pre, hist_pre['val_loss'], marker='o', linestyle='--', label='Val loss HF - Pretrain BF')
axes[0].plot(x_ft, hist_ft['train_loss'], marker='o', label='Train loss - Finetune HF')
axes[0].plot(x_ft, hist_ft['val_loss'], marker='o', linestyle='--', label='Val loss HF - Finetune HF')
axes[0].axvline(PRETRAIN_EPOCHS + 0.5, color='gray', linestyle=':', label='Transition BF -> HF')
axes[0].set_title('Evolution de la loss')
axes[0].set_xlabel('Epoch globale')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)
axes[0].legend(fontsize=8)

axes[1].plot(x_pre, hist_pre['val_acc'], marker='o', label='Val acc HF - Pretrain BF')
axes[1].plot(x_ft, hist_ft['val_acc'], marker='o', label='Val acc HF - Finetune HF')
axes[1].axvline(PRETRAIN_EPOCHS + 0.5, color='gray', linestyle=':', label='Transition BF -> HF')
axes[1].set_title('Evolution de la precision (validation HF)')
axes[1].set_xlabel('Epoch globale')
axes[1].set_ylabel('Accuracy (%)')
axes[1].grid(alpha=0.3)
axes[1].legend(fontsize=8)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig(png_path, dpi=180, bbox_inches='tight')
plt.show()
print('Figure sauvee:', png_path)

# --- W&B : log final + upload artefacts + finish ---
if USE_WANDB and _WANDB_AVAILABLE and wandb.run is not None:
    wandb.log({
        "test/accuracy_HF": test_hf_acc,
        "test/accuracy_BF": test_bf_acc,
        "test/accuracy_Mixte": test_mix_acc,
        "test/loss_HF": test_hf_loss,
        "test/loss_BF": test_bf_loss,
        "total_cost_CA": total_cost,
        "total_time_min": total_time_min,
    })
    wandb.summary["final/accuracy_HF"] = test_hf_acc
    wandb.summary["final/accuracy_BF"] = test_bf_acc
    wandb.summary["final/accuracy_Mixte"] = test_mix_acc
    wandb.summary["final/total_cost_CA"] = total_cost
    wandb.summary["final/total_time_min"] = total_time_min

    try:
        wandb.save(pth_path)
        wandb.save(json_path)
        wandb.save(png_path)
    except Exception as e:
        print(f"⚠️ wandb.save a échoué : {e}")

    wandb.finish()
    print("📡 Run W&B clôturé proprement.")
# Out:
# --- RESULTATS FINAUX (Imagewoof - Strategie 1) ---
# Test HF    : 53.68%
# Test BF    : 44.82%
# Test Mixte : 49.25%
# Cout total : 153160 CA
# Temps total: 0.83 min
# JSON sauve: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/results_strategy1_transfer_learning.json
# Model sauve: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/model_strategy1_transfer_learning.pth
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Figure sauvee: /content/drive/MyDrive/UTBM_PF22/results/Imagewoof/strategy1_transfer_learning_curves.png
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Finetune_HF/train_loss</td><td>█▅▄▃▂▂▁▁▁▁</td></tr><tr><td>Finetune_HF/val_accuracy</td><td>▁▁█▃▆▃▆▅▆▅</td></tr><tr><td>Finetune_HF/val_loss</td><td>█▃▁▃▁▅▄▆▇▇</td></tr><tr><td>Pretrain_BF/train_loss</td><td>█▇▆▆▅▄▄▃▂▁</td></tr><tr><td>Pretrain_BF/val_accuracy</td><td>▁▃▆▃▃▇▆█▇▅</td></tr><tr><td>Pretrain_BF/val_loss</td><td>▄▅▂▄▇▁▃▁▃█</td></tr><tr><td>cumulative_cost_CA</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>test/accuracy_BF</td><td>▁</td></tr><tr><td>test/accuracy_HF</td><td>▁</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Finetune_HF/train_loss</td><td>0.05047</td></tr><tr><td>Finetune_HF/val_accuracy</td><td>50</td></tr><tr><td>Finetune_HF/val_loss</td><td>1.70751</td></tr><tr><td>Pretrain_BF/train_loss</td><td>0.72255</td></tr><tr><td>Pretrain_BF/val_accuracy</td><td>35</td></tr><tr><td>Pretrain_BF/val_loss</td><td>2.69786</td></tr><tr><td>cumulative_cost_CA</td><td>153160</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>final/accuracy_BF</td><td>44.82057</td></tr><tr><td>final/accuracy_HF</td><td>53.67778</td></tr><tr><td>+14</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Strategie1_TransferLearning</strong> at: <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/zuc2bwtw' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity/runs/zuc2bwtw</a><br> View project at: <a href='https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity' target="_blank">https://wandb.ai/ivannvasic05-utbm/PF22-MultiFidelity</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20260430_103647-zuc2bwtw/logs</code>
# 📡 Run W&B clôturé proprement.

# %% [markdown]
# ## 6) Comparaison avec les baselines Imagewoof
# Charge les JSON deja produits dans `results/Imagewoof/` (baselines + strategie 1).

# %%
baseline_files = {
    'BL 1(HF)': 'results_baseline_HF.json',
    'BL 2(BF)': 'results_baseline_BF.json',
    'BL 3(MIXTE)': 'results_baseline_MIXTE.json',
    'Strategie 1(BF->HF)': 'results_strategy1_transfer_learning.json'
}

rows = []
for name, fn in baseline_files.items():
    p = os.path.join(RESULTS_DIR, fn)
    if os.path.exists(p):
        with open(p, 'r', encoding='utf-8') as f:
            d = json.load(f)
        rows.append((
            name,
            d.get('accuracy_HF', np.nan),
            d.get('accuracy_BF', np.nan),
            d.get('accuracy_Mixte', np.nan),
            d.get('total_cost_CA', np.nan),
            d.get('training_time_sec', np.nan) / 60.0 if 'training_time_sec' in d else d.get('total_time_min', np.nan)
        ))

if not rows:
    print('Aucun fichier JSON trouve pour la comparaison dans', RESULTS_DIR)
else:
    header = f"{'Modele (Imagewoof)':<24} {'HF%':>8} {'BF%':>8} {'Mixte%':>10} {'Cout(CA)':>12} {'Temps(min)':>12}"
    print(header)
    print('-' * len(header))
    for r in rows:
        print(f"{r[0]:<24} {r[1]:>8.2f} {r[2]:>8.2f} {r[3]:>10.2f} {r[4]:>12.0f} {r[5]:>12.2f}")
# Out:
# Modele (Imagewoof)            HF%      BF%     Mixte%     Cout(CA)   Temps(min)
# -------------------------------------------------------------------------------
# BL 1(HF)                    24.87    19.04      21.95       179800         0.39
# BL 2(BF)                    43.73    44.52      44.12       162520         1.00
# BL 3(MIXTE)                 47.19    47.24      47.21       342320         1.36
# Strategie 1(BF->HF)         53.68    44.82      49.25       153160         0.83
